# %%
import requests
from requests.api import request
import time
import json
import re
import random
import os
import pickle
import trio
import subprocess
import shutil
from enum import Enum
# import win32file
# win32file._setmaxstdio(8192)

PREVIOUS_REQUESTS_BACKUP_PATH = "./previousRequests/"


def get_valid_filename(name):
    s = str(name).strip().replace(" ", "_")
    s = re.sub(r"(?u)[^-\w.]", "", s)
    if s in {"", ".", ".."}:
        return "ErrorFileName" + str(random.randrange(100000))
    return s


def get_valid_path(path):
    s = str(path).strip().replace(" ", "_")
    s = re.sub(r"(?u)[^-\w./]", "", s)
    if s in {"", ".", ".."}:
        return "ErrorFileName" + str(random.randrange(100000))
    if s[-1] == ".":
        s += "_"
    return s


def dumpAPIRequest(fileName, data, path=PREVIOUS_REQUESTS_BACKUP_PATH):
    fullFileName = get_valid_path(path) + get_valid_filename(fileName) + ".bin"
    os.makedirs(os.path.dirname(fullFileName), exist_ok=True)
    with open(fullFileName, "wb") as outputFile:
        pickle.dump(data, outputFile)
    return fullFileName


def loadAPIRequest(fileName, path=PREVIOUS_REQUESTS_BACKUP_PATH):
    fullFileName = path + get_valid_filename(fileName) + ".bin"
    if not os.path.exists(fullFileName):
        return {}
    with open(fullFileName, "rb") as inputFile:
        data = pickle.load(inputFile)
    return data


def checkForAPIRequest(url, path=PREVIOUS_REQUESTS_BACKUP_PATH):
    return os.path.exists(
        path + get_valid_filename(url) + ".bin"
    )


def dumpJSON(fileName, data, path="./"):
    fullFileName = get_valid_path(path) + get_valid_filename(fileName) + ".json"
    os.makedirs(os.path.dirname(fullFileName), exist_ok=True)
    with open(fullFileName, "w") as outputFile:
        json.dump(data, outputFile, indent=6)
    return fullFileName


def loadJSON(fullFileName):
    if not os.path.exists(fullFileName):
        return {}
    with open(fullFileName, "r") as inputFile:
        data = json.load(inputFile)
    return data


def checkForJSON(fileName, path):
    fullFileName = get_valid_path(path) + get_valid_filename(fileName) + ".json"
    # return loadJSON(fullFileName) if os.path.exists(fullFileName) else {}
    return fullFileName if os.path.exists(fullFileName) else {}


def dumpGeneric(fileName, list, type="txt", path="./"):
    fullFileName = get_valid_path(path) + get_valid_filename(fileName) + "." + type
    os.makedirs(os.path.dirname(fullFileName), exist_ok=True)
    with open(fullFileName, "w") as outputFile:
        for item in list:
            outputFile.write(str(item) + "\n")
    return fullFileName


def nurseryReturn(nursery, assignee, location, func, *args):
    async def getReturn():
        assignee[location] = await func(*args)

    nursery.start_soon(getReturn)

# %%
SCRATCH_API = "https://api.scratch.mit.edu"
WAIT_TIME = 0.1
lastRequestTime = 0
timerLock = trio.Lock()
markLock = trio.Lock()
markedRequests = set({})
imageLock = trio.Lock()
markedImages = set({})
AUTH_ADDITION = "?x-token="


async def apiRequest(url):
    async with markLock:
        marked = url in markedRequests
        if not marked:
            markedRequests.add(url)
    if marked:
        while url in markedRequests:
            await trio.sleep(0.1)
    
    if checkForAPIRequest(url):
        return loadAPIRequest(url)

    async with timerLock:
        global lastRequestTime
        sleepTime = max(lastRequestTime + WAIT_TIME - time.time(), 0)
        # while(time.time() < lastRequestTime+WAIT_TIME):
        #     pass
        lastRequestTime = time.time()
    await trio.sleep(sleepTime)

    response = requests.get(url)
    data = response.json() if response.ok else {}

    dumpAPIRequest(url, data)
    markedRequests.remove(url)

    return data

async def imageGet(url, path="./", backupPath = PREVIOUS_REQUESTS_BACKUP_PATH):
    async with imageLock:
        marked = url in markedImages
        if not marked:
            markedImages.add(url)
    if marked:
        while url in markedImages:
            await trio.sleep(0.1)
    
    imageName = re.search("[^/]*.png", url).group()
    imageBackupPath = backupPath + imageName

    if not os.path.exists(imageBackupPath):
        imageRequest = requests.get(url, stream=True)
        if imageRequest.status_code == 200:
            os.makedirs(backupPath, exist_ok=True)
            with open(imageBackupPath, 'wb') as imageFile:
                imageRequest.raw.decode_content = True
                shutil.copyfileobj(imageRequest.raw, imageFile)
            markedImages.remove(url)
        else:
            markedImages.remove(url)
            print("Image not found: " + url)
            return

    imagePath = path + imageName
    os.makedirs(path, exist_ok=True)
    shutil.copy(imageBackupPath, imagePath)


async def getAllResults(url):
    limit = 40
    url = url + "?limit=" + str(limit) + "&offset="
    offset = 0
    singleList = await apiRequest(url + str(offset))
    all = singleList
    while len(singleList) >= limit:
        offset += limit
        singleList = await apiRequest(url + str(offset))
        if len(singleList) > 0:
            all += singleList
    return all


async def getAllResultsDateBased(url):
    limit = 40
    url = url + "?limit=" + str(limit)
    singleList = await apiRequest(url)
    all = singleList
    while len(singleList) >= limit:
        dateLimit = all[-1].datetime_created
        singleList = await apiRequest(url + "?dateLimit=" + str(dateLimit))
        if len(singleList) > 0:
            overlapIndex = singleList.index(all[-1]) + 1
            if overlapIndex < len(singleList):
                truncatedList = singleList[(singleList.index(all[-1]) + 1) :]
                if len(truncatedList) > 0:
                    all += truncatedList
    return all


async def getCommentsWithReplies(url):
    comments = await getAllResults(url)
    async with trio.open_nursery() as nursery:
        for comment in comments:
            if "reply_count" in comment.keys() and comment["reply_count"] > 0:
                # async def getReplies():
                #     comment["replies"] = await getAllResults(url + "/" + str(comment["id"]) + "/replies")
                # nursery.start_soon(getReplies)
                nurseryReturn(
                    nursery,
                    comment,
                    "replies",
                    getAllResults,
                    url + "/" + str(comment["id"]) + "/replies",
                )

            else:
                comment["replies"] = {}
                comment["reply_count"] = 0
    return comments

# %%
# project calls

projectsInfoAPIAddition = "/projects/"
projectInfoAPI = SCRATCH_API + projectsInfoAPIAddition

async def getProjectInfo(projectID):
    return await apiRequest(projectInfoAPI + str(projectID))

projectRemixesAPIAddition = "/remixes"
async def getProjectRemixes(projectID):
    return await getAllResults(projectInfoAPI + str(projectID) + projectRemixesAPIAddition)


# bonus helper function
userIDs = {}
async def getProjectUserName(projectID, userID=None):
    if userID is None or userID not in userIDs.keys():
        projectInfo = await getProjectInfo(projectID)
        if(projectInfo != {}):
            userIDs[userID] = projectInfo["author"]["username"]
            return userIDs[userID]
        else:
            return ""
    else:
        return userIDs[userID]

# %%
# studio calls

studioInfoAPIAddition = "/studios/"
studioInfoAPI = SCRATCH_API + studioInfoAPIAddition
async def getStudioInfo(studioID):
    return await apiRequest(studioInfoAPI + str(studioID))

studioActivityAPIAddition = "/activity"
async def getStudioActivity(studioID):
    return await getAllResults(studioInfoAPI + str(studioID) + studioActivityAPIAddition)

studioCommentsAPIAddition = "/comments"
async def getStudioComments(studioID):
    return await getCommentsWithReplies(studioInfoAPI + str(studioID) + studioCommentsAPIAddition)

studioCuratorsAPIAddition = "/curators"
async def getStudioCurators(studioID):
    return await getAllResults(studioInfoAPI + str(studioID) + studioCuratorsAPIAddition)

studioManagersAPIAddition = "/managers"
async def getStudioManagers(studioID):
    return await getAllResults(studioInfoAPI + str(studioID) + studioManagersAPIAddition)

studioProjectsAPIAddition = "/projects"
async def getStudioProjects(studioID):
    studioProjects = await getAllResults(studioInfoAPI + str(studioID) + studioProjectsAPIAddition)
    # async with trio.open_nursery() as nursery:
    #     for i in range(len(studioProjects)):
    #         nurseryReturn(nursery, studioProjects, i, getProjectInfo, studioProjects[i]["id"])
    return studioProjects

studioUserRoleAPIAddition = "/users/"
async def getStudioUserRole(studioID, userName, authToken):
    return await getAllResults(studioInfoAPI + str(studioID) + studioUserRoleAPIAddition + userName + AUTH_ADDITION + authToken)

# %%
# user calls

userInfoAPIAddition = "/users/"
userInfoAPI = SCRATCH_API + userInfoAPIAddition
async def getUserInfo(userName):
    return await apiRequest(userInfoAPI + str(userName))

userFavoritesAPIAddition = "/favorites"
async def getUserFavorites(userName):
    projects = await getAllResults(userInfoAPI + str(userName) + userFavoritesAPIAddition)
    async with trio.open_nursery() as nursery:
        for project in projects:
            nurseryReturn(nursery, project["author"], "username", getProjectUserName, project["id"], project["author"]["id"])
    return projects

userFollowersAPIAddition = "/followers"
async def getUserFollowers(userName):
    return await getAllResults(userInfoAPI + str(userName) + userFollowersAPIAddition)

userFollowingAPIAddition = "/following"
async def getUserFollowing(userName):
    return await getAllResults(userInfoAPI + str(userName) + userFollowingAPIAddition)

userFollowingStudiosAPIAddition = userFollowingAPIAddition + "/studios/projects"
async def getUserFollowingStudios(userName, authToken):
    return await getAllResults(userInfoAPI + str(userName) + userFollowingStudiosAPIAddition + AUTH_ADDITION + authToken)

userFollowingUsersActivityAPIAddition = userFollowingAPIAddition + "/users/activity"
async def getUserFollowingUsersActivity(userName, authToken):
    return await getAllResults(userInfoAPI + str(userName) + userFollowingUsersActivityAPIAddition + AUTH_ADDITION + authToken)

userFollowingUsersLovesAPIAddition = userFollowingAPIAddition + "/users/loves"
async def getUserFollowingUsersLoves(userName, authToken):
    return await getAllResults(userInfoAPI + str(userName) + userFollowingUsersLovesAPIAddition + AUTH_ADDITION + authToken)

userFollowingUsersProjectsAPIAddition = userFollowingAPIAddition + "/users/projects"
async def getUserFollowingUsersProjects(userName, authToken):
    return await getAllResults(userInfoAPI + str(userName) + userFollowingUsersProjectsAPIAddition + AUTH_ADDITION + authToken)

userInvitesAPIAddition = "/invites"
async def getUserInvites(userName, authToken):
    return await getAllResults(userInfoAPI + str(userName) + userInvitesAPIAddition + AUTH_ADDITION + authToken)

userMessagesAPIAddition = "/messages"
async def getUserMessages(userName, authToken):
    return await getAllResults(userInfoAPI + str(userName) + userMessagesAPIAddition + AUTH_ADDITION + authToken)

userAlertsAPIAddition = "/messages/admin"
async def getUserAlerts(userName, authToken):
    return await getAllResults(userInfoAPI + str(userName) + userAlertsAPIAddition + AUTH_ADDITION + authToken)

userUnreadMessagesCountAPIAddition = "/messages/count"
async def getUserUnreadMessagesCount(userName, authToken):
    return await getAllResults(userInfoAPI + str(userName) + userUnreadMessagesCountAPIAddition + AUTH_ADDITION + authToken)

userProjectsAPIAddition = "/projects"
async def getUserProjects(userName):
    projects = await getAllResults(userInfoAPI + str(userName) + userProjectsAPIAddition)
    for project in projects:
        project["author"]["username"] = userName
    return projects

userRecentlyViewedAPIAddition = "/projects/recentlyviewed"
async def getUserRecentlyViewed(userName, authToken):
    return await getAllResults(userInfoAPI + str(userName) + userRecentlyViewedAPIAddition + AUTH_ADDITION + authToken)

userProjectCommentsAPIAddition = "/comments"
userProjectsAPIAdditionMiddle = "/projects/"
async def getUserProjectComments(userName, projectID):
    return await getCommentsWithReplies(userInfoAPI + str(userName) + userProjectsAPIAdditionMiddle + str(projectID) + userProjectCommentsAPIAddition)

userProjectStudiosAPIAddition = "/studios"
async def getUserProjectStudiosAPI(userName, projectID):
    return await getAllResults(userInfoAPI + str(userName) + userProjectsAPIAdditionMiddle + str(projectID) + userProjectStudiosAPIAddition)

userUnsharedProjectAPIAddition = "/visibility"
async def getUserUnsharedProject(userName, projectID):
    return await getCommentsWithReplies(userInfoAPI + str(userName) + userProjectsAPIAdditionMiddle + str(projectID) + userUnsharedProjectAPIAddition)

userStudiosAPIAddition = "/studios/curate"
async def getUserStudios(userName):
    return await getAllResults(userInfoAPI + str(userName) + userStudiosAPIAddition)

# %%
projectsToDownload = {}
urlsToDownload = set({})

scratchBaseURL = "https://scratch.mit.edu/"
userURL = scratchBaseURL + "users/"
projectURL = scratchBaseURL + "projects/"
studioURL = scratchBaseURL + "studios/"

levelCountLock = trio.Lock()
levelCount = {}

class LevelCountTypes(Enum):
    DONE = "Done"
    TOTAL = "Total"

async def handleLevelCount(level, countType, outputPath=""):
    async with levelCountLock:
        if level not in levelCount.keys():
            levelCount[level] = {}
            for levelCountType in LevelCountTypes:
                levelCount[level][levelCountType] = {"Count": 0, "Lock": trio.Lock()}
    async with levelCount[level][countType]["Lock"]:
        levelCount[level][countType]["Count"] += 1
    print(("\t"*level) + str(levelCount[level][LevelCountTypes.DONE]["Count"]) + " / " + str(levelCount[level][LevelCountTypes.TOTAL]["Count"]) + "\t" + outputPath)


async def getProjectData(
    userName, projectID, level=0, outputPath="./", authUserName=None, authToken=None
):
    urlsToDownload.add(projectURL + str(projectID))

    project = {}
    project["projectInfo"] = await getProjectInfo(projectID)
    if project["projectInfo"] == {}:
        return ""


    outputPath += get_valid_path(project["projectInfo"]["title"]) + "/"
    print(outputPath)

    await imageGet(project["projectInfo"]["image"], outputPath)

    if projectID not in projectsToDownload.keys():
        projectsToDownload[projectID] = []

    projectsToDownload[projectID].append(outputPath)


    fileName = get_valid_filename(project["projectInfo"]["title"])

    jsonCheck = checkForJSON(fileName, outputPath)
    if jsonCheck != {}:
        return jsonCheck

    await handleLevelCount(level, LevelCountTypes.TOTAL)

    async with trio.open_nursery() as nursery:
        nurseryReturn(nursery, project, "projectRemixes", getProjectRemixes, projectID)
        nurseryReturn(
            nursery,
            project,
            "projectStudios",
            getUserProjectStudiosAPI,
            userName,
            projectID,
        )
        nurseryReturn(
            nursery,
            project,
            "projectComments",
            getUserProjectComments,
            userName,
            projectID,
        )


    if level > 0:
        level -= 1

        async with trio.open_nursery() as nursery:
            for projectRemix in project["projectRemixes"]:
                nurseryReturn(
                    nursery,
                    projectRemix,
                    "projectData",
                    getProjectData,
                    projectRemix["author"]["username"],
                    projectRemix["id"],
                    level,
                    outputPath + "remixes/",
                    authUserName,
                    authToken,
                )
            for projectStudio in project["projectStudios"]:
                nurseryReturn(
                    nursery,
                    projectStudio,
                    "studioData",
                    getStudioData,
                    projectStudio["id"],
                    level,
                    outputPath + "studios/",
                    authUserName,
                    authToken,
                )
            for projectComment in project["projectComments"]:
                nurseryReturn(
                    nursery,
                    projectComment,
                    "userData",
                    getUserData,
                    projectComment["author"]["username"],
                    level,
                    outputPath + "commentUsers/",
                    authUserName,
                    authToken,
                )


    outputFileName = dumpJSON(fileName, project, outputPath)
    await handleLevelCount(level+1, LevelCountTypes.DONE, outputPath)
    return outputFileName



async def getStudioData(
    studioID, level=0, outputPath="./", authUserName=None, authToken=None
):
    urlsToDownload.add(studioURL + str(studioID))

    studio = {}
    studio["studioInfo"] = await getStudioInfo(studioID)


    outputPath += get_valid_path(studio["studioInfo"]["title"]) + "/"
    print(outputPath)

    await imageGet(studio["studioInfo"]["image"], outputPath)

    fileName = get_valid_filename(studio["studioInfo"]["title"])

    jsonCheck = checkForJSON(fileName, outputPath)
    if jsonCheck != {}:
        return jsonCheck
    
    await handleLevelCount(level, LevelCountTypes.TOTAL)


    async with trio.open_nursery() as nursery:
        nurseryReturn(nursery, studio, "studioActivity", getStudioActivity, studioID)
        nurseryReturn(nursery, studio, "studioComments", getStudioComments, studioID)
        nurseryReturn(nursery, studio, "studioCurators", getStudioCurators, studioID)
        nurseryReturn(nursery, studio, "studioManagers", getStudioManagers, studioID)
        nurseryReturn(nursery, studio, "studioProjects", getStudioProjects, studioID)
        if authUserName is not None:
            nurseryReturn(
                nursery,
                studio,
                "studioUserRole",
                getStudioUserRole,
                studioID,
                authUserName,
                authToken,
            )


    if level > 0:
        level -= 1

        async with trio.open_nursery() as nursery:
            for studioCurator in studio["studioCurators"]:
                nurseryReturn(
                    nursery,
                    studioCurator,
                    "userData",
                    getUserData,
                    studioCurator["username"],
                    level,
                    outputPath + "curators/",
                    authUserName,
                    authToken,
                )
            for studioManager in studio["studioManagers"]:
                nurseryReturn(
                    nursery,
                    studioManager,
                    "userData",
                    getUserData,
                    studioManager["username"],
                    level,
                    outputPath + "managers/",
                    authUserName,
                    authToken,
                )
            for studioProject in studio["studioProjects"]:
                nurseryReturn(
                    nursery,
                    studioProject,
                    "projectData",
                    getProjectData,
                    studioProject["username"], # studioProject["author"]["username"],
                    studioProject["id"],
                    level,
                    outputPath + "projects/",
                    authUserName,
                    authToken,
                )


    outputFileName = dumpJSON(fileName, studio, outputPath)
    await handleLevelCount(level+1, LevelCountTypes.DONE, outputPath)
    return outputFileName



async def getUserData(
    userName, level=0, outputPath="./", authUserName=None, authToken=None,
):
    urlsToDownload.add(userURL + userName)

    user = {}
    user["userInfo"] = await getUserInfo(userName)


    outputPath += get_valid_path(userName) + "/"
    print(outputPath)

    await imageGet(user["userInfo"]["profile"]["images"]["90x90"], outputPath)

    fileName = get_valid_filename(userName)

    jsonCheck = checkForJSON(fileName, outputPath)
    if jsonCheck != {}:
        return jsonCheck
    
    await handleLevelCount(level, LevelCountTypes.TOTAL)

    async with trio.open_nursery() as nursery:
        nurseryReturn(nursery, user, "userFavorites", getUserFavorites, userName)
        nurseryReturn(nursery, user, "userFollowers", getUserFollowers, userName)
        nurseryReturn(nursery, user, "userFollowing", getUserFollowing, userName)
        nurseryReturn(nursery, user, "userProjects", getUserProjects, userName)
        nurseryReturn(nursery, user, "userStudios", getUserStudios, userName)
        if userName == authUserName:
            frontPageStuffName = "userCurrentFrontPage"
            user[frontPageStuffName] = {}
            nurseryReturn(
                nursery,
                user[frontPageStuffName],
                "Projects in Studios I'm Following",
                getUserFollowingStudios,
                authUserName,
                authToken,
            )
            nurseryReturn(
                nursery,
                user[frontPageStuffName],
                "What's Happening?",
                getUserFollowingUsersActivity,
                authUserName,
                authToken,
            )
            nurseryReturn(
                nursery,
                user[frontPageStuffName],
                "Projects Loved by Scratchers I'm Following",
                getUserFollowingUsersLoves,
                authUserName,
                authToken,
            )
            nurseryReturn(
                nursery,
                user[frontPageStuffName],
                "Projects by Scratchers I'm Following",
                getUserFollowingUsersProjects,
                authUserName,
                authToken,
            )
            notifications = "userNotifications"
            user[notifications] = {}
            nurseryReturn(
                nursery,
                user[notifications],
                "invites",
                getUserInvites,
                authUserName,
                authToken,
            )
            nurseryReturn(
                nursery,
                user[notifications],
                "messages",
                getUserMessages,
                authUserName,
                authToken,
            )
            nurseryReturn(
                nursery,
                user[notifications],
                "alerts",
                getUserAlerts,
                authUserName,
                authToken,
            )
            nurseryReturn(
                nursery,
                user[notifications],
                "unreadMessagesCount",
                getUserUnreadMessagesCount,
                authUserName,
                authToken,
            )
            nurseryReturn(
                nursery,
                user,
                "userRecentlyViewed",
                getUserRecentlyViewed,
                authUserName,
                authToken,
            )
    
    if level > 0:
        level -= 1
        async with trio.open_nursery() as nursery:
            for userFavorite in user["userFavorites"]:
                nurseryReturn(
                    nursery,
                    userFavorite,
                    "projectData",
                    getProjectData,
                    userFavorite["author"]["username"],
                    userFavorite["id"],
                    level,
                    outputPath + "favorites/",
                    authUserName,
                    authToken,
                )
            for userFollower in user["userFollowers"]:
                nurseryReturn(
                    nursery,
                    userFollower,
                    "userData",
                    getUserData,
                    userFollower["username"],
                    level,
                    outputPath + "followers/",
                    authUserName,
                    authToken,
                )
            for userFollow in user["userFollowing"]:
                nurseryReturn(
                    nursery,
                    userFollow,
                    "userData",
                    getUserData,
                    userFollow["username"],
                    level,
                    outputPath + "following/",
                    authUserName,
                    authToken,
                )
            for userProject in user["userProjects"]:
                nurseryReturn(
                    nursery,
                    userProject,
                    "projectData",
                    getProjectData,
                    userProject["author"]["username"],
                    userProject["id"],
                    level,
                    outputPath + "projects/",
                    authUserName,
                    authToken,
                )
            for userStudio in user["userStudios"]:
                nurseryReturn(
                    nursery,
                    userStudio,
                    "studioData",
                    getStudioData,
                    userStudio["id"],
                    level,
                    outputPath + "studios/",
                    authUserName,
                    authToken,
                )


    outputFileName = dumpJSON(fileName, user, outputPath)
    await handleLevelCount(level+1, LevelCountTypes.DONE, outputPath)
    return outputFileName

# %%
# MARK_DATA = {"mark"}

# for fileName in os.listdir(PREVIOUS_REQUESTS_BACKUP_PATH):
#     fileDirectory = os.path.join(PREVIOUS_REQUESTS_BACKUP_PATH, fileName)
#     delete = False
#     with open(fileDirectory, "rb") as inputFile:
#         delete = pickle.load(inputFile) == MARK_DATA
#     if delete:
#         os.remove(fileDirectory)

# %%
projectsToDownload = {}
urlsToDownload = set({})

# %%
authData = loadJSON("scratchAuthenticationToken.json")
trio.run(getUserData, authData["username"], authData["level"], "./", authData["username"], authData["x-token"])
# Out:
# ./fespadea/
# 			0 / 1
# ./fespadea/studios/my_games/
# ./fespadea/studios/my_mini_series/
# Image not found: https://cdn2.scratch.mit.edu/get_image/gallery/1125412_170x100.png
# ./fespadea/studios/my_sprite_projects/
# 		0 / 1
# ./fespadea/studios/mario_and_luigi_videos/
# 		0 / 2
# ./fespadea/studios/bobs_projects/
# ./fespadea/studios/spanish_learning/
# 		0 / 3
# 		0 / 4
# ./fespadea/studios/jrtroopa_palace/
# 		0 / 5
# ./fespadea/projects/mario_bros._vs_blooper_bros._/
# 		0 / 6
# ./fespadea/projects/death/
# 		0 / 7
# ./fespadea/projects/mario_rocks/
# ./fespadea/projects/game/
# 		0 / 8
# 		0 / 9
# ./fespadea/projects/jrtroopa_bros._2/
# ./fespadea/projects/jrtroopa_bros._4/
# 		0 / 10
# ./fespadea/projects/jrtroopa_bros._5/
# 		0 / 11
# ./fespadea/projects/jrtroopa_bros._/
# 		0 / 12
# ./fespadea/projects/jrtroopa_bros.3/
# 		0 / 13
# ./fespadea/projects/jrtroopa_bros._6/
# 		0 / 14
# ./fespadea/projects/banana_man_becomes_a_super_hero/
# ./fespadea/projects/shark/
# 		0 / 15
# ./fespadea/projects/dont_call_a_shark_dumb/
# 		0 / 16
# 		0 / 17
# ./fespadea/projects/banana_man_game/
# ./fespadea/projects/dialogo/
# 		0 / 18
# ./fespadea/projects/battle_wars/
# 		0 / 19
# ./fespadea/projects/super_mario_galaxy/
# 		0 / 20
# ./fespadea/projects/kirby_scrollers/
# ./fespadea/projects/yoshi_scrollers/
# 		0 / 21
# ./fespadea/projects/skate_boarding_scrolling/
# ./fespadea/projects/wormy/
# 		0 / 22
# ./fespadea/projects/jail_break/
# 		0 / 23
# ./fespadea/projects/sonic/
# 		0 / 24
# ./fespadea/projects/food/
# 		0 / 25
# 		0 / 26
# ./fespadea/projects/Add_yourself_fighting_giant_dry_bowser11/
# ./fespadea/projects/DONT_QUIT1/
# 		0 / 27
# 		0 / 28
# ./fespadea/projects/join_the_egg_hunt/
# ./fespadea/projects/moving_sprites/
# 		0 / 29
# ./fespadea/projects/dounut_man/
# 		0 / 30
# ./fespadea/projects/shrinky/
# 		0 / 31
# 		0 / 32
# ./fespadea/projects/my_first_demo/
# ./fespadea/projects/mario_and_luigi/
# 		0 / 33
# 		0 / 34
# ./fespadea/projects/dance/
# 		0 / 35
# ./fespadea/projects/mario_and_luigi2/
# 		0 / 36
# ./fespadea/projects/mario_and_luigi_3/
# ./fespadea/projects/fun_with_fish/
# ./fespadea/projects/my_space_slideshow/
# 		0 / 37
# ./fespadea/projects/sounds_code_needed/
# 		0 / 38
# ./fespadea/projects/Scratch_is_falling_apart11/
# ./fespadea/projects/funny_clip/
# 		0 / 39
# Image not found: https://cdn2.scratch.mit.edu/get_image/project/1052842_480x360.png
# ./fespadea/projects/my_first_script_video/
# ./fespadea/projects/join_running_in_the_rain/
# 		0 / 40
# ./fespadea/projects/Spiderman_music_video/
# ./fespadea/projects/Hello_Kitty_Sprites/
# 		0 / 41
# ./fespadea/projects/spanish_cake/
# 		0 / 42
# ./fespadea/projects/my_entry_for_the_coloring_contest/
# 		0 / 43
# ./fespadea/projects/cool_clip/
# ./fespadea/projects/new_contest/
# 		0 / 44
# ./fespadea/projects/my_tinies/
# ./fespadea/projects/my_wizard101_glitch_experience/
# 		0 / 45
# ./fespadea/projects/yet_another_tiny/
# 		0 / 46
# ./fespadea/projects/my_tinies_together/
# 		0 / 47
# 		0 / 48
# ./fespadea/projects/more_tinies/
# ./fespadea/projects/all_my_tinies_together_2/
# ./fespadea/projects/my_entry_to_sprite_masters_contest/
# ./fespadea/projects/my_other_entry_to_sprite_masters_contest/
# ./fespadea/projects/My_jiggler_techy/
# 		0 / 49
# ./fespadea/projects/my_scribble/
# ./fespadea/projects/my_second_jiggle/
# ./fespadea/projects/my_entry_to_08jackts_contest/
# 		0 / 50
# ./fespadea/projects/thanks_spritemaster/
# ./fespadea/projects/contest_winner/
# 		0 / 51
# ./fespadea/projects/new_song_I_made_it/
# ./fespadea/projects/yet_another_great_song_by_fespdea/
# 		0 / 52
# ./fespadea/projects/man_another_song_by_fespadea/
# ./fespadea/projects/fespadea_song/
# ./fespadea/projects/bobs_adventures_preview/
# ./fespadea/projects/bob_stuck_in_lunch_chamber/
# ./fespadea/projects/bobs_fall/
# ./fespadea/projects/bobs_box/
# 		0 / 53
# ./fespadea/projects/bobs_mail/
# 		0 / 54
# ./fespadea/projects/bobs_friend/
# 		0 / 55
# ./fespadea/projects/my_eye-guy/
# 		0 / 56
# ./fespadea/projects/bobs_run/
# 		0 / 57
# ./fespadea/projects/fespadea_contest/
# 		0 / 58
# ./fespadea/projects/misunder_standing/
# 		0 / 59
# ./fespadea/projects/credit_to_spriteman22/
# 		0 / 60
# ./fespadea/projects/bobs_fall_2/
# 		0 / 61
# ./fespadea/projects/bob_sleep_walks/
# ./fespadea/projects/bobs_fall_3/
# 		0 / 62
# ./fespadea/projects/100_messages/
# 		0 / 63
# ./fespadea/projects/bobs_play/
# ./fespadea/projects/more_credit_to_spriteman22/
# 		0 / 64
# ./fespadea/projects/just_to_make_sure_you_know_the_guys_in_the_bobs_adventures_series/
# 		0 / 65
# 		0 / 66
# ./fespadea/projects/number_one_veiwer_prize/
# ./fespadea/projects/entry_for_08jacket/
# ./fespadea/projects/ADD_A_PLUSH_SCRATCHER1/
# ./fespadea/projects/add_yourself_flying1REMIXED1/
# ./fespadea/projects/bobs_fight/
# ./fespadea/projects/bob_rolled/
# 		0 / 67
# ./fespadea/projects/bobs_enemy/
# ./fespadea/projects/The_Beach_part_6_spoof/
# 		0 / 68
# ./fespadea/projects/winner/
# 		0 / 69
# 		0 / 70
# ./fespadea/projects/people_from_Bobs_adventures_bios/
# ./fespadea/projects/The_Beach_part_9_spoof/
# ./fespadea/projects/green_ball/
# ./fespadea/projects/GLITCH/
# 		0 / 71
# ./fespadea/projects/for_swifties_background_characters/
# 		0 / 72
# ./fespadea/projects/my_I_love_choclate_remix/
# ./fespadea/projects/bobs_merry_toastgiving/
# 		0 / 73
# ./fespadea/projects/my_entry_to_nodears_contest/
# ./fespadea/projects/needed_block/
# ./fespadea/projects/toast_war/
# 		0 / 74
# ./fespadea/projects/swifty2_fan_art/
# 		0 / 75
# ./fespadea/projects/fun_with_a_square/
# 		0 / 76
# ./fespadea/projects/contest_time/
# ./fespadea/projects/shoop_the_pus/
# 		0 / 77
# ./fespadea/projects/bobs_trip_to_the_museum/
# ./fespadea/projects/here_you_go_eagleman/
# 		0 / 78
# 		0 / 79
# ./fespadea/projects/new_winner/
# ./fespadea/projects/bob_tries_to_rob_a_bank/
# 		0 / 80
# ./fespadea/projects/bobs_vocal_chords/
# ./fespadea/projects/bob_tells_the_duck_story/
# ./fespadea/projects/bob_and_the_pie/
# 		0 / 81
# 		0 / 82
# ./fespadea/projects/bob_as_a_human_plus_new_song/
# ./fespadea/projects/add_youlf_to_the_ski_lifts1/
# 		0 / 83
# ./fespadea/projects/contest_kinda/
# 		0 / 84
# ./fespadea/projects/bob_life_of_the_job_guy/
# 		0 / 85
# ./fespadea/projects/my_Air_entry/
# 		0 / 86
# ./fespadea/projects/how_to_draw_bob/
# 		0 / 87
# 		0 / 88
# ./fespadea/projects/Catch_that_gumball11/
# 		0 / 89
# ./fespadea/projects/contest_entry_for_spritemasters_christmas_tree_contest/
# ./fespadea/projects/wawa_hoagie_AMV/
# 		0 / 90
# 		0 / 91
# ./fespadea/projects/my_entry_for_haleyalmes_rpg/
# 		0 / 92
# ./fespadea/projects/how_to_export_a_sprite/
# ./fespadea/projects/bad_animation/
# 		0 / 93
# 		0 / 94
# ./fespadea/projects/contest_fanart_for_hidden_heart/
# 		0 / 95
# ./fespadea/projects/some_art/
# ./fespadea/projects/epic_battle_between_bob_and_mario/
# 		0 / 96
# ./fespadea/projects/Add_yourself_Trying_to_catch_sonic11/
# 		0 / 97
# ./fespadea/projects/happy_human_bob/
# 		0 / 98
# ./fespadea/projects/bobs_dude_day/
# ./fespadea/projects/epic_picture/
# 		0 / 99
# 		0 / 100
# ./fespadea/projects/bob_is_mean/
# 		0 / 101
# ./fespadea/projects/my_entry_to_cookinaters_contest/
# ./fespadea/projects/burst_the_hedgehog_series_entry/
# ./fespadea/projects/dialgamans_contest_entry/
# 		0 / 102
# 		0 / 103
# ./fespadea/projects/whirlpool_sounds/
# 		0 / 104
# ./fespadea/projects/Bob_the_movie_preview/
# 		0 / 105
# ./fespadea/projects/bob_meets_whirlpool/
# ./fespadea/projects/Bob_the_movie_part_1/
# 		0 / 106
# ./fespadea/projects/bob_meets_bob_detective/
# 		0 / 107
# ./fespadea/projects/bob_gets_hit_by_x-cube/
# 		0 / 108
# 		0 / 109
# ./fespadea/projects/bob_the_movie_part_2/
# 		0 / 110
# ./fespadea/projects/my_entry_to_nuthouse/
# ./fespadea/projects/Remix_Chain_Add_your_own_pen._1/
# 		0 / 111
# 		0 / 112
# ./fespadea/projects/bobs_Christmas_is_creepy_AMV/
# ./fespadea/projects/cool_art/
# 		0 / 113
# 		0 / 114
# ./fespadea/projects/words/
# ./fespadea/projects/toon_bros._sprite_pack_small/
# 		0 / 115
# ./fespadea/projects/tails_doll_sprite_freaky/
# 		0 / 116
# ./fespadea/projects/add_yourself_helping_build_furry_club_read_notes_too1/
# ./fespadea/projects/bobs_merry_waffle_adventure/
# 		0 / 117
# 		0 / 118
# ./fespadea/projects/speghetti_pickle_or_the_epic_dancing_waffle/
# ./fespadea/projects/weegee_doll/
# 		0 / 119
# ./fespadea/projects/add_yourself_to_the_giant_stinky_cheese1/
# ./fespadea/projects/add_your_own_fakegee/
# ./fespadea/projects/films/
# 		0 / 120
# 		0 / 121
# ./fespadea/projects/night/
# ./fespadea/projects/not_so_good_sparta_remix_by_me/
# ./fespadea/projects/sound_stopper/
# ./fespadea/projects/its_my_B-day/
# 		0 / 122
# ./fespadea/projects/sprite_pack/
# 		0 / 123
# ./fespadea/projects/malleo_is_saved/
# 		0 / 124
# ./fespadea/projects/wierd/
# ./fespadea/projects/sprite_pack_v2/
# 		0 / 125
# 		0 / 126
# ./fespadea/projects/sprite_pack_v3/
# ./fespadea/projects/epic_fall/
# 		0 / 127
# ./fespadea/projects/sprite_pack_v4/
# 		0 / 128
# ./fespadea/projects/random_sprite/
# 		0 / 129
# ./fespadea/projects/random_sprite_2/
# 		0 / 130
# ./fespadea/projects/random_sprite_4/
# 		0 / 131
# ./fespadea/projects/random_sprite_5/
# ./fespadea/projects/whoops/
# 		0 / 132
# 		0 / 133
# ./fespadea/projects/Add_yourself_with_what_you_got_for_Christmas1/
# ./fespadea/projects/bobs_banana/
# 		0 / 134
# ./fespadea/projects/cool_stickman/
# 		0 / 135
# ./fespadea/projects/haunted_mansion/
# ./fespadea/projects/just_a_little_something/
# 		0 / 136
# ./fespadea/projects/random_sprite_3/
# 		0 / 137
# ./fespadea/projects/just_a_chase/
# 		0 / 138
# ./fespadea/projects/new_gallery/
# 		0 / 139
# ./fespadea/projects/fosters_home_for_imaginary_friends_sprites/
# ./fespadea/projects/my_website/
# ./fespadea/projects/some_yoshis_island_sprites/
# ./fespadea/projects/advertising_for_mario555/
# 		0 / 140
# ./fespadea/projects/contest_entry_for_mario555/
# ./fespadea/projects/bobs_funny_faces/
# 		0 / 141
# ./fespadea/projects/just_something_I_thought_would_be_fun_to_post/
# ./fespadea/projects/tailsdroid819_standing_drawing/
# 		0 / 142
# ./fespadea/projects/tailsdroid819_flying_drawing/
# 		0 / 143
# ./fespadea/projects/tailsdroid819_spin_attack_drawing/
# 		0 / 144
# ./fespadea/projects/tailsdroid819_walking_drawing/
# ./fespadea/projects/please_willied/
# ./fespadea/projects/contest/
# ./fespadea/projects/arnold_for_spritemasters_contest/
# ./fespadea/projects/day_in_the_life_of_job_guy_2/
# ./fespadea/projects/Add_your_anthro_relaxing111/
# 		0 / 145
# ./fespadea/projects/young_chuck_norris_AMV/
# 		0 / 146
# ./fespadea/projects/D_with_color/
# ./fespadea/projects/eyelashes/
# 		0 / 147
# ./fespadea/projects/Pokemon_Palkia_And_Dialgas_Duel_to_the_Destiny11/
# 		0 / 148
# ./fespadea/projects/sprites_v1/
# ./fespadea/projects/raven_rabids_intro/
# 		0 / 149
# 		0 / 150
# ./fespadea/projects/sprites_v2/
# ./fespadea/projects/3_things_that_would_make_me_happy/
# 		0 / 151
# 		0 / 152
# ./fespadea/projects/for_dialgaman/
# ./fespadea/projects/my_entry_for_mini-series/
# 		0 / 153
# 		0 / 154
# ./fespadea/projects/bob_phil_and_steve_go_dancing/
# ./fespadea/projects/domo_sprite_pack/
# 		0 / 155
# 		0 / 156
# ./fespadea/projects/have_fun_with_the_snaky/
# 		0 / 157
# ./fespadea/projects/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/
# ./fespadea/projects/bobs_bad_robot_day/
# 		0 / 158
# ./fespadea/projects/gazofios_contest_entry/
# 		0 / 159
# ./fespadea/projects/the_landry_machine/
# 		0 / 160
# ./fespadea/projects/the_return_of_dk_AMV/
# 		0 / 161
# ./fespadea/projects/tailsdroid819_in_super_form/
# 		0 / 162
# 		0 / 163
# ./fespadea/projects/ADD_UR_ANTI-QUITTER111/
# ./fespadea/projects/funny_scene/
# 		0 / 164
# ./fespadea/projects/add_ur_anthro_flying1/
# 		0 / 165
# 		0 / 166
# ./fespadea/projects/some_random_mario_sprites/
# ./fespadea/projects/something_I_forgot_to_put_in_the_mario_sprite_pack/
# 		0 / 167
# 		0 / 168
# ./fespadea/projects/some_random_luigi_sprites/
# 		0 / 169
# ./fespadea/projects/some_random_yoshi_sprites/
# ./fespadea/projects/jb_elmo_barney_and_dora_sprites/
# 		0 / 170
# ./fespadea/projects/sprites_v3/
# 		0 / 171
# 		0 / 172
# ./fespadea/projects/epic_sprites/
# ./fespadea/projects/epic_sprites_2/
# 		0 / 173
# 		0 / 174
# ./fespadea/projects/KAJ/
# ./fespadea/projects/KAJ_attack/
# 		0 / 175
# 		0 / 176
# ./fespadea/projects/kirbys_epic_quest/
# 		0 / 177
# ./fespadea/projects/epic_kirby_sprites/
# 		0 / 178
# ./fespadea/projects/epic_kirby_sprites_2/
# ./fespadea/projects/3_random_sprites/
# 		0 / 179
# 		0 / 180
# ./fespadea/projects/my_entry_for_the_bagz_RPG_by_willieD/
# 		0 / 181
# ./fespadea/projects/ideas_anybody/
# 		0 / 182
# ./fespadea/projects/I_take_requests/
# 		0 / 183
# ./fespadea/projects/super_mario_galaxy_2_sprites/
# ./fespadea/projects/the_trigger/
# 		0 / 184
# 		0 / 185
# ./fespadea/projects/water/
# 		0 / 186
# ./fespadea/projects/balloon/
# 		0 / 187
# ./fespadea/projects/awesome/
# ./fespadea/projects/my_entry_for_spies_RPG/
# 		0 / 188
# ./fespadea/projects/dr._pepper/
# 		0 / 189
# ./fespadea/projects/Pengy_rpg1/
# 		0 / 190
# ./fespadea/projects/just_a_tune/
# 		0 / 191
# ./fespadea/projects/scat_man/
# 		0 / 192
# ./fespadea/projects/Add_your_own_little_person/
# ./fespadea/projects/Bagz_rpg_ideas/
# 		0 / 193
# ./fespadea/projects/how_to_say_Fespadea/
# 		0 / 194
# ./fespadea/projects/sound_effects/
# 		0 / 195
# 		0 / 196
# ./fespadea/projects/darkside/
# ./fespadea/projects/advertisement/
# 		0 / 197
# 		0 / 198
# ./fespadea/projects/funny_shorts/
# ./fespadea/projects/bobs_fall_4/
# 		0 / 199
# ./fespadea/projects/my_accounts/
# 		0 / 200
# ./fespadea/projects/scatman_part_2/
# 		0 / 201
# ./fespadea/projects/random_sprites/
# 		0 / 202
# ./fespadea/projects/pokemon_sprite_pack/
# 		0 / 203
# ./fespadea/projects/random_sprites_2/
# ./fespadea/projects/game_night/
# 		0 / 204
# ./fespadea/projects/chuck_norris_sprite/
# 		0 / 205
# ./fespadea/projects/my_contest_entry_for_BobbyFs_gumball_contest/
# 		0 / 206
# ./fespadea/projects/small_star_wars_sprite_pack/
# 		0 / 207
# ./fespadea/projects/bob_meets_wierd_bunny_guy/
# 		0 / 208
# 		0 / 209
# ./fespadea/projects/bob_stinks_at_everything_including_getting_a_girlfriend/
# 		0 / 210
# ./fespadea/projects/bob_the_movie_part_3/
# 		0 / 211
# 		0 / 212
# ./fespadea/projects/small_star_fox_sprite_pack/
# ./fespadea/projects/bob_is_attacked/
# 		0 / 213
# ./fespadea/projects/bob_vs_darth_vader/
# ./fespadea/projects/bob_the_movie_part_4/
# 		0 / 214
# ./fespadea/projects/something_dumb/
# 		0 / 215
# ./fespadea/projects/hungry/
# 		0 / 216
# ./fespadea/projects/The_thinga-magiger/
# 		0 / 217
# ./fespadea/projects/the_return_of_dk_AMV_finished/
# 		0 / 218
# ./fespadea/projects/bobs_weird_halloween/
# 		0 / 219
# ./fespadea/projects/the_great_disaster/
# 		0 / 220
# 		0 / 221
# ./fespadea/projects/pickles/
# 		0 / 222
# ./fespadea/projects/mario_vs_luigi_part_3/
# 		0 / 223
# ./fespadea/projects/Bob_vs._Darth_Vader_Part_2/
# 		0 / 224
# ./fespadea/projects/mario_and_stuff_for_science-2/
# 		0 / 225
# ./fespadea/projects/16-bit_michael_jackson_sprite/
# ./fespadea/projects/new_sprite/sounds_pack_fox_captain_falcon_dr._mario_yoshi_8-bit_meta_sonic_and_more/
# 		0 / 226
# ./fespadea/projects/Michael_Jackson_demo/
# 		0 / 227
# 		0 / 228
# ./fespadea/projects/top_down_duck_hunt/
# ./fespadea/projects/jr._troopa_bros._7/
# 		0 / 229
# 		0 / 230
# ./fespadea/projects/mario_and_luigi4/
# ./fespadea/projects/Star_Wars_Enterance_remix/
# 		0 / 231
# ./fespadea/projects/the_paper_mario_yoshis_meet_each_other/
# 		0 / 232
# 		0 / 233
# ./fespadea/projects/blast_speed_or_shoot/
# ./fespadea/projects/catch_the_food/
# 		0 / 234
# ./fespadea/projects/bob_the_movie_part_5/
# ./fespadea/following/Gazoofio/
# 		0 / 235
# 		0 / 236
# ./fespadea/following/WillieD/
# 		0 / 237
# ./fespadea/following/DORYEN/
# 		0 / 238
# ./fespadea/following/mrdead578/
# 		0 / 239
# ./fespadea/following/lu9/
# ./fespadea/following/man556/
# 		0 / 240
# ./fespadea/following/MIGUEL_12_/
# 		0 / 241
# 		0 / 242
# ./fespadea/following/mrdinosaur/
# ./fespadea/following/GameMasterMichael/
# 		0 / 243
# 		0 / 244
# ./fespadea/following/hayleyalmes/
# ./fespadea/following/cjfbaseball/
# 		0 / 245
# ./fespadea/following/princessfifi/
# 		0 / 246
# ./fespadea/following/kennamz/
# 		0 / 247
# ./fespadea/following/muymik123/
# 		0 / 248
# 		0 / 249
# ./fespadea/following/fartyboy/
# 		0 / 250
# ./fespadea/following/pie/
# 		0 / 251
# ./fespadea/following/Gatwer/
# ./fespadea/following/m44/
# 		0 / 252
# ./fespadea/following/MeiaAlsup/
# 		0 / 253
# 		0 / 254
# ./fespadea/following/illusionist/
# 		0 / 255
# ./fespadea/following/SampleProjectsTeam/
# ./fespadea/following/GX2000/
# 		0 / 256
# ./fespadea/following/cliclub/
# 		0 / 257
# ./fespadea/following/Dave9/
# 		0 / 258
# 		0 / 259
# ./fespadea/following/Tanner-FBI/
# 		0 / 260
# ./fespadea/following/stardudes/
# ./fespadea/following/SpriteMaster/
# 		0 / 261
# 		0 / 262
# ./fespadea/following/danielross98/
# 		0 / 263
# ./fespadea/following/mario555/
# 		0 / 264
# ./fespadea/following/didiboy/
# ./fespadea/following/Targethero/
# 		0 / 265
# ./fespadea/following/cesars/
# 		0 / 266
# 		0 / 267
# ./fespadea/following/S65/
# 		0 / 268
# ./fespadea/following/coolstuff/
# ./fespadea/following/uzay/
# 		0 / 269
# 		0 / 270
# ./fespadea/following/jr-r2-d2/
# 		0 / 271
# ./fespadea/following/Nad11/
# ./fespadea/following/nikkiperson2/
# 		0 / 272
# 		0 / 273
# ./fespadea/following/Ultimate_dark_spine/
# 		0 / 274
# ./fespadea/following/Astro947/
# ./fespadea/following/Krottle/
# 		0 / 275
# 		0 / 276
# ./fespadea/following/bchby10/
# 		0 / 277
# ./fespadea/following/REMIXERS/
# ./fespadea/following/Spriteman22/
# 		0 / 278
# 		0 / 279
# ./fespadea/following/luvaboi/
# ./fespadea/following/supermarioboy/
# 		0 / 280
# ./fespadea/following/Dialgaman/
# 		0 / 281
# ./fespadea/following/Cozyhut3/
# 		0 / 282
# 		0 / 283
# ./fespadea/following/TheExplodingCheez/
# 		0 / 284
# ./fespadea/following/eagleman/
# 		0 / 285
# ./fespadea/following/JJmanrulez/
# ./fespadea/following/08jackt/
# 		0 / 286
# ./fespadea/following/Pommy15642/
# 		0 / 287
# ./fespadea/following/Lucario621/
# 		0 / 288
# 		0 / 289
# ./fespadea/following/JIM13243/
# ./fespadea/following/strutsen/
# 		0 / 290
# ./fespadea/following/lcoopman/
# 		0 / 291
# 		0 / 292
# ./fespadea/following/KatJoy/
# 		0 / 293
# ./fespadea/following/archmage/
# 		0 / 294
# ./fespadea/following/masterpie124/
# 		0 / 295
# ./fespadea/following/thelegoman/
# 		0 / 296
# ./fespadea/following/philchicken/
# 		0 / 297
# ./fespadea/following/StickKing/
# ./fespadea/following/All4one/
# 		0 / 298
# ./fespadea/following/yoshidude56/
# 		0 / 299
# 		0 / 300
# ./fespadea/following/kevin11111/
# ./fespadea/following/mhsuperyeah/
# 		0 / 301
# 		0 / 302
# ./fespadea/following/starwarsfanatic44/
# 		0 / 303
# ./fespadea/following/Puppies4ever/
# 		0 / 304
# ./fespadea/following/number1superstar/
# ./fespadea/following/Nodear/
# 		0 / 305
# ./fespadea/following/scratchU8/
# 		0 / 306
# 		0 / 307
# ./fespadea/following/spark_the_hedgehog/
# ./fespadea/following/onethreetwo/
# 		0 / 308
# 		0 / 309
# ./fespadea/following/bill65/
# 		0 / 310
# ./fespadea/following/LucasGamer/
# 		0 / 311
# ./fespadea/following/Cookinator/
# ./fespadea/following/straightsonicDX/
# 		0 / 312
# 		0 / 313
# ./fespadea/following/PokemonPerson365/
# ./fespadea/following/Swift8520/
# 		0 / 314
# 		0 / 315
# ./fespadea/following/zxcvbnmkj/
# ./fespadea/following/Groudon297/
# 		0 / 316
# 		0 / 317
# ./fespadea/following/BenDaMan/
# ./fespadea/following/darthvader424242/
# 		0 / 318
# ./fespadea/following/johndo77/
# 		0 / 319
# 		0 / 320
# ./fespadea/following/RocksAndFire/
# 		0 / 321
# ./fespadea/following/Raki-Tak/
# ./fespadea/following/BobbyF/
# 		0 / 322
# ./fespadea/following/CaptanAwesome/
# 		0 / 323
# ./fespadea/following/catfan8/
# 		0 / 324
# 		0 / 325
# ./fespadea/following/PokemonGameCreater/
# Image not found: https://cdn2.scratch.mit.edu/get_image/user/647393_90x90.png?v=
# ./fespadea/following/Lex-Creatrix/
# 		0 / 326
# 		0 / 327
# ./fespadea/following/Maki-Tak/
# 		0 / 328
# ./fespadea/following/LatiasLV100/
# ./fespadea/following/NuggetMan126/
# 		0 / 329
# ./fespadea/following/GameHutSoftware/
# 		0 / 330
# 		0 / 331
# ./fespadea/following/Hidden-Heart/
# 		0 / 332
# ./fespadea/following/colorfusion/
# ./fespadea/following/burstthehedgehog/
# 		0 / 333
# 		0 / 334
# ./fespadea/following/x-cube/
# ./fespadea/following/sph12/
# 		0 / 335
# 		0 / 336
# ./fespadea/following/conman135/
# ./fespadea/following/bcrc/
# 		0 / 337
# ./fespadea/following/BANANAGUY1000/
# 		0 / 338
# ./fespadea/following/reedfe/
# 		0 / 339
# 		0 / 340
# Image not found: https://cdn2.scratch.mit.edu/get_image/user/7925_90x90.png?v=
# ./fespadea/following/TheWeegee/
# ./fespadea/following/thesuperguidegames/
# 		0 / 341
# ./fespadea/following/RHY3756547/
# 		0 / 342
# ./fespadea/following/goalkeepery/
# 		0 / 343
# 		0 / 344
# ./fespadea/following/hamstermon/
# ./fespadea/following/TheMalleo/
# 		0 / 345
# 		0 / 346
# ./fespadea/following/Beeman98/
# ./fespadea/following/Epic99/
# 		0 / 347
# ./fespadea/following/Oreo-Cookies/
# 		0 / 348
# 		0 / 349
# ./fespadea/following/ToxicQuillz/
# ./fespadea/following/Tails-Doll/
# 		0 / 350
# 		0 / 351
# ./fespadea/following/zeldameister/
# ./fespadea/following/pieclip/
# 		0 / 352
# ./fespadea/following/poopadopolis/
# 		0 / 353
# 		0 / 354
# ./fespadea/following/Sparky123/
# 		0 / 355
# ./fespadea/following/Zomonster9/
# ./fespadea/following/Shadowdrawer123/
# 		0 / 356
# 		0 / 357
# ./fespadea/following/turtlewarrior/
# ./fespadea/following/Pinkjello34/
# 		0 / 358
# 		0 / 359
# ./fespadea/following/BlahBlahRatSheep/
# 		0 / 360
# ./fespadea/following/tip7/
# ./fespadea/following/webby68/
# 		0 / 361
# ./fespadea/following/scratchjmk/
# 		0 / 362
# ./fespadea/following/supergarfield/
# 		0 / 363
# 		0 / 364
# ./fespadea/following/bowser555/
# ./fespadea/following/THEUGLYBARNACLE/
# 		0 / 365
# ./fespadea/following/Bandit150/
# 		0 / 366
# 		0 / 367
# ./fespadea/following/SpriteMaster_Tester/
# ./fespadea/following/Darkthehedgehog/
# 		0 / 368
# ./fespadea/following/statg/
# 		0 / 369
# ./fespadea/following/bauiop90/
# 		0 / 370
# ./fespadea/following/RyeBread27/
# 		0 / 371
# 		0 / 372
# ./fespadea/following/TheMusicMan/
# ./fespadea/following/Pointlessstuff/
# 		0 / 373
# 		0 / 374
# ./fespadea/following/x-sprite/
# ./fespadea/following/santaisonfacebook/
# 		0 / 375
# 		0 / 376
# ./fespadea/following/sa6m/
# ./fespadea/following/GlitchSprite/
# 		0 / 377
# ./fespadea/following/forme01/
# 		0 / 378
# 		0 / 379
# ./fespadea/following/Sashmo10/
# 		0 / 380
# ./fespadea/following/MeTwo/
# 		0 / 381
# ./fespadea/following/cheeseman100/
# ./fespadea/following/Tails-Doll-/
# 		0 / 382
# 		0 / 383
# ./fespadea/following/awesome58/
# 		0 / 384
# ./fespadea/following/pat010/
# 		0 / 385
# ./fespadea/following/Willig/
# 		0 / 386
# ./fespadea/following/Astro947RMXs/
# ./fespadea/following/Maximum200/
# 		0 / 387
# ./fespadea/following/philliesareawesome/
# 		0 / 388
# 		0 / 389
# ./fespadea/following/philliesfan78/
# ./fespadea/following/Dialgaman_test/
# 		0 / 390
# ./fespadea/following/fespadea_tester/
# 		0 / 391
# 		0 / 392
# ./fespadea/following/BaggyProductions/
# ./fespadea/following/sk8rdude29/
# 		0 / 393
# ./fespadea/following/juggalo64/
# 		0 / 394
# 		0 / 395
# ./fespadea/following/8000dude/
# 		0 / 396
# ./fespadea/following/Cloakedyoshi/
# 		0 / 397
# ./fespadea/following/tailsdroid819/
# ./fespadea/following/shadowfan54/
# 		0 / 398
# ./fespadea/following/zigtech/
# 		0 / 399
# ./fespadea/following/kmc123/
# 		0 / 400
# ./fespadea/following/CoolerThanIce/
# 		0 / 401
# ./fespadea/following/swifty2testaccount/
# 		0 / 402
# 		0 / 403
# ./fespadea/following/awesomedude16/
# ./fespadea/following/megaspark/
# 		0 / 404
# 		0 / 405
# ./fespadea/following/NintendoDaniel/
# ./fespadea/following/tonyz101/
# 		0 / 406
# 		0 / 407
# ./fespadea/following/Nitrox510/
# ./fespadea/following/random64/
# 		0 / 408
# 		0 / 409
# ./fespadea/following/SM_Sneak_Peeks/
# 		0 / 410
# ./fespadea/following/Weegee/
# 		0 / 411
# ./fespadea/following/bboy72/
# 		0 / 412
# ./fespadea/following/xmbo/
# 		0 / 413
# ./fespadea/following/momohoho1/
# 		0 / 414
# ./fespadea/following/h2i3/
# ./fespadea/following/unicorn_meat/
# 		0 / 415
# 		0 / 416
# ./fespadea/following/adetoito2/
# 		0 / 417
# ./fespadea/following/Gabew/
# ./fespadea/following/WillieD_Fakemon/
# 		0 / 418
# ./fespadea/following/PieNinja/
# 		0 / 419
# 		0 / 420
# ./fespadea/following/SonicSega7/
# 		0 / 421
# ./fespadea/following/Metaknightking/
# 		0 / 422
# ./fespadea/following/yo567/
# ./fespadea/following/BWOG/
# 		0 / 423
# ./fespadea/following/photot1234/
# 		0 / 424
# ./fespadea/following/Jacobthehedgehog/
# 		0 / 425
# 		0 / 426
# ./fespadea/following/Stevelo/
# ./fespadea/following/horido6/
# 		0 / 427
# ./fespadea/following/GhostofForme01/
# 		0 / 428
# ./fespadea/following/Scoobydoo67/
# 		0 / 429
# 		0 / 430
# ./fespadea/following/alldaykade28471/
# 		0 / 431
# ./fespadea/following/MarioFans/
# ./fespadea/following/pokeywokey/
# 		0 / 432
# 		0 / 433
# ./fespadea/following/pacmanfan03/
# 		0 / 434
# ./fespadea/following/jonzo/
# 		0 / 435
# ./fespadea/following/Colkadome/
# 		0 / 436
# ./fespadea/following/041/
# ./fespadea/following/fulldroid/
# 		0 / 437
# 		0 / 438
# ./fespadea/following/Axarr/
# ./fespadea/following/Caramellstar51/
# 		0 / 439
# ./fespadea/following/PandaGuy/
# 		0 / 440
# ./fespadea/following/kranda2000/
# 		0 / 441
# ./fespadea/following/BobbyF_Extras/
# 		0 / 442
# 		0 / 443
# ./fespadea/following/awsomon/
# ./fespadea/following/SwiftNinja32/
# 		0 / 444
# ./fespadea/following/Toonosh/
# 		0 / 445
# 		0 / 446
# ./fespadea/following/Flaredaeevee/
# 		0 / 447
# ./fespadea/following/JJROCKER/
# 		0 / 448
# ./fespadea/following/ComputerCrazy/
# ./fespadea/following/BIG-red-BUTTON/
# 		0 / 449
# 		0 / 450
# ./fespadea/following/awesomeprojects42/
# ./fespadea/following/imld/
# 		0 / 451
# 		0 / 452
# ./fespadea/following/legomaster90/
# ./fespadea/following/Wolfman38/
# 		0 / 453
# ./fespadea/following/chickensmacker/
# 		0 / 454
# ./fespadea/following/yakman/
# 		0 / 455
# ./fespadea/following/minimaker123/
# 		0 / 456
# 		0 / 457
# ./fespadea/following/wallfish/
# 		0 / 458
# ./fespadea/following/Mr-Herriman/
# ./fespadea/following/emirhanpppp/
# 		0 / 459
# 		0 / 460
# ./fespadea/following/OverBakedPotato/
# ./fespadea/following/dragonuzi/
# 		0 / 461
# ./fespadea/following/Papatai/
# 		0 / 462
# 		0 / 463
# ./fespadea/following/WatsonLJ/
# ./fespadea/following/SwiftyRevived/
# 		0 / 464
# 		0 / 465
# 		0 / 466
# 		0 / 467
# ./fespadea/followers/cookie135/
# 		0 / 468
# ./fespadea/followers/Paperboy200/
# 		0 / 469
# ./fespadea/followers/ridermaster246/
# 		0 / 470
# ./fespadea/followers/parker1998/
# 		0 / 471
# ./fespadea/followers/20baisju/
# 		0 / 472
# ./fespadea/followers/Memestar/
# 		0 / 473
# ./fespadea/followers/savannahrouge1/
# ./fespadea/followers/warriormaker327/
# 		0 / 474
# ./fespadea/followers/aage10/
# 		0 / 475
# ./fespadea/followers/Jellyman123/
# 		0 / 476
# 		0 / 477
# ./fespadea/followers/sircoops652/
# ./fespadea/followers/FireStar124/
# 		0 / 478
# ./fespadea/followers/SuperMarioBloopers/
# ./fespadea/followers/jacksonarab/
# 		0 / 479
# ./fespadea/followers/Mr20ThCenturySamInc/
# 		0 / 480
# ./fespadea/followers/Nightmare_moonPony/
# 		0 / 481
# ./fespadea/followers/speedyrang396/
# 		0 / 482
# 		0 / 483
# ./fespadea/followers/Celsaschmilenvania/
# 		0 / 484
# ./fespadea/followers/hatakenokodmo/
# ./fespadea/followers/link9924/
# ./fespadea/followers/BobFrenkid/
# 		0 / 485
# ./fespadea/followers/arthurreed/
# 		0 / 486
# 		0 / 487
# ./fespadea/followers/Bienestar2000/
# ./fespadea/followers/4aidken944/
# 		0 / 488
# 		0 / 489
# ./fespadea/followers/Platformerz4ever/
# 		0 / 490
# ./fespadea/followers/CJSybs/
# 		0 / 491
# 		0 / 492
# 		0 / 493
# ./fespadea/projects/banana_man_becomes_a_super_hero/commentUsers/maxheroman44821/
# 	0 / 1
# ./fespadea/projects/kirby_scrollers/commentUsers/Hitchy227/
# 	0 / 2
# ./fespadea/projects/skate_boarding_scrolling/commentUsers/rnstata/
# ./fespadea/projects/DONT_QUIT1/remixes/DONT_QUIT11/
# ./fespadea/projects/join_the_egg_hunt/remixes/join_the_egg_hunt1/
# 	0 / 3
# 	0 / 4
# ./fespadea/projects/mario_and_luigi/studios/The_Mario_and_Luigi_gallery/
# 	0 / 5
# ./fespadea/projects/funny_clip/commentUsers/fireball360/
# ./fespadea/projects/Spiderman_music_video/commentUsers/basilhythe/
# 	0 / 6
# ./fespadea/projects/Spiderman_music_video/commentUsers/GS456789/
# ./fespadea/projects/Spiderman_music_video/commentUsers/HankJGoldeton/
# 	0 / 7
# ./fespadea/projects/Hello_Kitty_Sprites/commentUsers/swimmerchick9/
# ./fespadea/projects/Hello_Kitty_Sprites/commentUsers/arisha_the_scratcher/
# 	0 / 8
# 	0 / 9
# 	0 / 10
# 	0 / 11
# ./fespadea/projects/My_jiggler_techy/studios/Jigglers_RPG/
# 	0 / 12
# ./fespadea/projects/bobs_friend/remixes/SHDS/
# 	0 / 13
# ./fespadea/projects/bob_sleep_walks/remixes/the_roller_coaster_of_terror_for_fespedea/
# 	0 / 14
# ./fespadea/projects/add_yourself_flying1REMIXED1/remixes/add_yourself_flying1REMIXED11/
# 	0 / 15
# ./fespadea/projects/for_swifties_background_characters/studios/School_dilemma_entrys/
# 	0 / 16
# ./fespadea/projects/shoop_the_pus/commentUsers/temat123/
# ./fespadea/projects/shoop_the_pus/studios/shoop_da_woop/
# ./fespadea/projects/shoop_the_pus/studios/Get_1000_games_until_2015/
# ./fespadea/projects/shoop_the_pus/studios/Shoop_Da_Whoop_Club/
# 	0 / 17
# 	0 / 18
# 	0 / 19
# ./fespadea/projects/some_art/studios/Drawing_and_other_arts/
# 	0 / 20
# ./fespadea/projects/Add_yourself_Trying_to_catch_sonic11/remixes/Add_yourself_Trying_to_catch_sonic1112/
# ./fespadea/projects/happy_human_bob/commentUsers/JoelGamer/
# 	0 / 21
# 	0 / 22
# ./fespadea/projects/my_entry_to_cookinaters_contest/remixes/The_Bobman_Award_Ceremony/
# ./fespadea/projects/Remix_Chain_Add_your_own_pen._1/remixes/Remix_Chain_Add_your_own_pen._/
# ./fespadea/projects/Remix_Chain_Add_your_own_pen._1/commentUsers/Scratchycat123/
# 	0 / 23
# 	0 / 24
# ./fespadea/projects/toon_bros._sprite_pack_small/commentUsers/gmapps/
# ./fespadea/projects/toon_bros._sprite_pack_small/studios/Sprite_Sprites/
# ./fespadea/projects/toon_bros._sprite_pack_small/studios/Tradutor/
# 	0 / 25
# ./fespadea/projects/toon_bros._sprite_pack_small/studios/The_Master_Studio_Of_Project/
# Image not found: https://cdn2.scratch.mit.edu/get_image/gallery/33769764_170x100.png
# 	0 / 26
# ./fespadea/projects/toon_bros._sprite_pack_small/studios/Untitled_Studio/
# 	0 / 27
# ./fespadea/projects/toon_bros._sprite_pack_small/studios/sprite_maker_studio/
# Image not found: https://cdn2.scratch.mit.edu/get_image/gallery/25897437_170x100.png
# ./fespadea/projects/toon_bros._sprite_pack_small/studios/Sprite_Mania/
# 	0 / 28
# 	0 / 29
# 	0 / 30
# ./fespadea/projects/toon_bros._sprite_pack_small/studios/Sprite_Makers/
# ./fespadea/projects/toon_bros._sprite_pack_small/studios/Ultimate_Sprite_Packs/
# 	0 / 31
# ./fespadea/projects/toon_bros._sprite_pack_small/studios/Sprite_Packs/
# ./fespadea/projects/toon_bros._sprite_pack_small/studios/Sprite_Projects/
# 	0 / 32
# ./fespadea/projects/toon_bros._sprite_pack_small/remixes/clauces/
# 	0 / 33
# 	0 / 34
# ./fespadea/projects/toon_bros._sprite_pack_small/remixes/Luigi_Cherche_Un_Num_dune_meuf/
# ./fespadea/projects/toon_bros._sprite_pack_small/remixes/toon_bros._sprite_pack_small_remix/
# 	0 / 35
# ./fespadea/projects/bobs_merry_waffle_adventure/studios/DaWaffle_Clan/
# 	0 / 36
# ./fespadea/projects/sound_stopper/commentUsers/SmurfEthan09/
# 	0 / 37
# ./fespadea/projects/sprite_pack/commentUsers/Waffles9999/
# 	0 / 38
# ./fespadea/projects/bobs_banana/commentUsers/turkey3/
# 	0 / 39
# ./fespadea/projects/bobs_funny_faces/commentUsers/clarent/
# 	0 / 40
# ./fespadea/projects/eyelashes/studios/Randomizer/
# 	0 / 41
# ./fespadea/projects/eyelashes/commentUsers/dinashell/
# ./fespadea/projects/Pokemon_Palkia_And_Dialgas_Duel_to_the_Destiny11/studios/ACTION_REPLAY_CODES_FOR_POKEMON/
# 	0 / 42
# 	0 / 43
# ./fespadea/projects/Pokemon_Palkia_And_Dialgas_Duel_to_the_Destiny11/commentUsers/firelord8199/
# 	0 / 44
# ./fespadea/projects/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/commentUsers/gandalf12345/
# ./fespadea/projects/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/commentUsers/Ninjakn133263/
# ./fespadea/projects/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/commentUsers/SnowyLion6400000/
# ./fespadea/projects/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/studios/add_yourself_running_from_a_giant_stickman_remixes/
# 	0 / 45
# 	0 / 46
# Image not found: https://cdn2.scratch.mit.edu/get_image/gallery/25556036_170x100.png
# ./fespadea/projects/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/studios/LETS_ADD_EVERTHING/
# 	0 / 47
# ./fespadea/projects/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/studios/svpanda_fan_club/
# 	0 / 48
# ./fespadea/projects/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/studios/For_DONNIEISAWESOME/
# 	0 / 49
# ./fespadea/projects/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/studios/lets_get_10000_projects/
# ./fespadea/projects/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/remixes/me_on_him/
# 	0 / 50
# 	0 / 51
# ./fespadea/projects/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/remixes/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1_remix/
# 	0 / 52
# ./fespadea/projects/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/remixes/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1_remix/
# ./fespadea/projects/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/remixes/ADD_YOURSELF_RUNNING_FROM_TEAM_DARK/
# 	0 / 53
# ./fespadea/projects/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/remixes/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/
# 	0 / 54
# 	0 / 55
# 	0 / 56
# 	0 / 57
# ./fespadea/projects/some_random_luigi_sprites/studios/SPRITES_SCRIPTS_BACKDROPS_AND_SOUNDS/
# ./fespadea/projects/some_random_luigi_sprites/commentUsers/LUIGIMAN306/
# ./fespadea/projects/some_random_luigi_sprites/commentUsers/bitz/
# 	0 / 58
# 	0 / 59
# 	0 / 60
# ./fespadea/projects/kirbys_epic_quest/commentUsers/pipibug/
# 	0 / 61
# ./fespadea/projects/super_mario_galaxy_2_sprites/commentUsers/Dobby454/
# 	0 / 62
# ./fespadea/projects/scat_man/commentUsers/cjmartineau0205/
# ./fespadea/projects/scat_man/commentUsers/EZZAR/
# 	0 / 63
# ./fespadea/projects/scat_man/remixes/scat_man/
# 	0 / 64
# ./fespadea/projects/Add_your_own_little_person/remixes/Add_your_own_little_person1/
# 	0 / 65
# ./fespadea/projects/Add_your_own_little_person/remixes/Add_your_own_little_person/
# ./fespadea/projects/Add_your_own_little_person/remixes/Add_your_own_little_person/
# ./fespadea/projects/funny_shorts/commentUsers/Xx_Teanny_xX/
# ./fespadea/projects/funny_shorts/commentUsers/derpysanicface/
# ./fespadea/projects/funny_shorts/commentUsers/NotoriousDawg/
# 	0 / 66
# 	0 / 67
# 	0 / 68
# ./fespadea/projects/funny_shorts/commentUsers/tabbyblackcat101/
# ./fespadea/projects/funny_shorts/studios/fast_studio/
# 	0 / 69
# 	0 / 70
# ./fespadea/projects/random_sprites_2/commentUsers/ccoders004/
# 	0 / 71
# ./fespadea/projects/bob_stinks_at_everything_including_getting_a_girlfriend/commentUsers/lolhaha123456789/
# 	0 / 72
# ./fespadea/projects/small_star_fox_sprite_pack/commentUsers/ssjSpencario/
# ./fespadea/projects/small_star_fox_sprite_pack/commentUsers/sonicfan497/
# ./fespadea/projects/small_star_fox_sprite_pack/commentUsers/SerialGamer/
# 	0 / 73
# 	0 / 74
# 	0 / 75
# ./fespadea/projects/something_dumb/commentUsers/giantfatty/
# ./fespadea/projects/something_dumb/commentUsers/mikeben/
# ./fespadea/projects/The_thinga-magiger/commentUsers/tailsdoll101/
# 	0 / 76
# ./fespadea/projects/the_return_of_dk_AMV_finished/studios/add_all_your_projects/
# 	0 / 77
# ./fespadea/projects/the_return_of_dk_AMV_finished/studios/hi/
# ./fespadea/projects/the_return_of_dk_AMV_finished/commentUsers/Scillog/
# 	0 / 78
# 	0 / 79
# ./fespadea/projects/the_return_of_dk_AMV_finished/commentUsers/Henrybomb/
# ./fespadea/projects/the_return_of_dk_AMV_finished/commentUsers/curiouscrab/
# 	0 / 80
# 	0 / 81
# ./fespadea/projects/the_return_of_dk_AMV_finished/commentUsers/trolley8/
# 	0 / 82
# ./fespadea/projects/the_return_of_dk_AMV_finished/commentUsers/Eterpay/
# 	0 / 83
# 	0 / 84
# 	0 / 85
# ./fespadea/projects/mario_vs_luigi_part_3/commentUsers/sk8rboi33/
# 	0 / 86
# ./fespadea/projects/16-bit_michael_jackson_sprite/remixes/16-bit_michael_jackson_sprite_remix/
# ./fespadea/projects/16-bit_michael_jackson_sprite/remixes/16-bit_michael_jackson_sprite_remix/
# ./fespadea/projects/16-bit_michael_jackson_sprite/remixes/micheal_jackson_beat_it_thriller_together_JUST_DANCE/
# ./fespadea/projects/16-bit_michael_jackson_sprite/remixes/16-bit_michael_jackson_sprite_remix/
# 	0 / 87
# 	0 / 88
# ./fespadea/projects/16-bit_michael_jackson_sprite/remixes/Michael_Jackson_smooth_criminal/
# ./fespadea/projects/16-bit_michael_jackson_sprite/remixes/Michael_Jackson/
# 	0 / 89
# 	0 / 90
# ./fespadea/projects/16-bit_michael_jackson_sprite/remixes/Michael_Jackson_Super_Mario_Bros._/
# 	0 / 91
# ./fespadea/projects/16-bit_michael_jackson_sprite/studios/can_we_get_1000000_projects_before_2019/
# 	0 / 92
# ./fespadea/projects/16-bit_michael_jackson_sprite/studios/MINERPRO2014s_Rad_Studio/
# ./fespadea/projects/16-bit_michael_jackson_sprite/commentUsers/Nesser09/
# 	0 / 93
# ./fespadea/projects/16-bit_michael_jackson_sprite/commentUsers/Phionex17/
# ./fespadea/projects/new_sprite/sounds_pack_fox_captain_falcon_dr._mario_yoshi_8-bit_meta_sonic_and_more/commentUsers/Vicodinator/
# 	0 / 94
# 	0 / 95
# ./fespadea/projects/new_sprite/sounds_pack_fox_captain_falcon_dr._mario_yoshi_8-bit_meta_sonic_and_more/commentUsers/tintitan3/
# 	0 / 96
# ./fespadea/projects/new_sprite/sounds_pack_fox_captain_falcon_dr._mario_yoshi_8-bit_meta_sonic_and_more/commentUsers/SFORSTAMPYXX/
# 	0 / 97
# ./fespadea/projects/new_sprite/sounds_pack_fox_captain_falcon_dr._mario_yoshi_8-bit_meta_sonic_and_more/commentUsers/bluefish5/
# ./fespadea/projects/new_sprite/sounds_pack_fox_captain_falcon_dr._mario_yoshi_8-bit_meta_sonic_and_more/commentUsers/tails1928/
# 	0 / 98
# ./fespadea/projects/new_sprite/sounds_pack_fox_captain_falcon_dr._mario_yoshi_8-bit_meta_sonic_and_more/studios/Untitled_Studio/
# 	0 / 99
# ./fespadea/projects/new_sprite/sounds_pack_fox_captain_falcon_dr._mario_yoshi_8-bit_meta_sonic_and_more/studios/Awesome_sprites/
# Image not found: https://cdn2.scratch.mit.edu/get_image/gallery/6032847_170x100.png
# 	0 / 100
# 	0 / 101
# 	0 / 102
# 	0 / 103
# ./fespadea/projects/top_down_duck_hunt/commentUsers/Ava_Lanche_24/
# 	0 / 104
# ./fespadea/projects/bob_the_movie_part_5/commentUsers/Overwhelmed4ever/
# 	0 / 105
# ./fespadea/following/cjfbaseball/studios/curtis_fry/
# ./fespadea/following/cjfbaseball/projects/sports/
# ./fespadea/following/cjfbaseball/projects/yankees/
# ./fespadea/following/cjfbaseball/projects/5_MarbleRacer/
# 	0 / 106
# 	0 / 107
# ./fespadea/following/cjfbaseball/projects/Robot_party/
# 	0 / 108
# ./fespadea/following/cjfbaseball/projects/WeDo_1_MagicWand/
# ./fespadea/following/cjfbaseball/projects/short_halloween_story/
# 	0 / 109
# 	0 / 110
# 	0 / 111
# ./fespadea/following/cjfbaseball/followers/Monster99/
# ./fespadea/following/cjfbaseball/followers/moffisawesome/
# 	0 / 112
# 	0 / 113
# ./fespadea/following/Gatwer/following/Nilzu07TheGialls/
# 	0 / 114
# ./fespadea/following/GX2000/followers/marioandluigistar/
# ./fespadea/following/GX2000/followers/Triforce_of_Courage/
# ./fespadea/following/GX2000/followers/ss45gogeta/
# 	0 / 115
# ./fespadea/following/GX2000/followers/SonicMan901/
# 	0 / 116
# ./fespadea/following/GX2000/followers/oliverp/
# 	0 / 117
# ./fespadea/following/GX2000/followers/kaykaypie/
# 	0 / 118
# 	0 / 119
# ./fespadea/following/GX2000/followers/StJosephsPrimary/
# ./fespadea/following/GX2000/followers/Screenslime/
# 	0 / 120
# 	0 / 121
# ./fespadea/following/GX2000/followers/Benba/
# ./fespadea/following/GX2000/followers/scratchyguy212/
# 	0 / 122
# ./fespadea/following/GX2000/followers/brookiebear17/
# 	0 / 123
# ./fespadea/following/GX2000/followers/drnero/
# 	0 / 124
# ./fespadea/following/GX2000/followers/jaja910/
# ./fespadea/following/GX2000/followers/broadbent/
# 	0 / 125
# ./fespadea/following/GX2000/followers/Agge/
# 	0 / 126
# ./fespadea/following/GX2000/followers/pielover1234/
# 	0 / 127
# 	0 / 128
# ./fespadea/following/GX2000/followers/llamallama/
# 	0 / 129
# ./fespadea/following/GX2000/followers/Ninja49/
# 	0 / 130
# ./fespadea/following/GX2000/followers/scritch1/
# 	0 / 131
# ./fespadea/following/GX2000/followers/Ketchup13/
# ./fespadea/following/GX2000/followers/barbara888/
# 	0 / 132
# 	0 / 133
# ./fespadea/following/GX2000/followers/RazorGliscor78/
# 	0 / 134
# ./fespadea/following/GX2000/followers/HD123/
# ./fespadea/following/GX2000/followers/snowkilla/
# 	0 / 135
# ./fespadea/following/GX2000/followers/AddMeAsAFriendToo/
# 	0 / 136
# ./fespadea/following/GX2000/followers/UGWG/
# 	0 / 137
# 	0 / 138
# 	0 / 139
# 	0 / 140
# ./fespadea/following/GX2000/projects/Wipeout_2.1/
# ./fespadea/following/GX2000/projects/AccountChange/
# ./fespadea/following/GX2000/projects/Darkspine_cat_V0.001/
# ./fespadea/following/GX2000/projects/add_your_self_to_the_waste_land111/
# 	0 / 141
# ./fespadea/following/GX2000/projects/Ultimate_battle_V0.5c_now_with_preloader/
# 	0 / 142
# 	0 / 143
# ./fespadea/following/GX2000/projects/Ultimate_battle_V0.5B/
# ./fespadea/following/GX2000/projects/Add_Things_Surfing-2/
# 	0 / 144
# ./fespadea/following/GX2000/projects/Perfect_Sidescrolling_Engine_v1.0_remix/
# 	0 / 145
# ./fespadea/following/GX2000/projects/Join_the_boulder_run/
# 	0 / 146
# ./fespadea/following/GX2000/projects/Super_sonic_say_what/
# ./fespadea/following/GX2000/projects/3D_knight/
# 	0 / 147
# 	0 / 148
# ./fespadea/following/GX2000/projects/my_game/
# ./fespadea/following/GX2000/studios/megaman_stuff/
# 	0 / 149
# 	0 / 150
# ./fespadea/following/cliclub/followers/BigDolphin/
# 	0 / 151
# 	0 / 152
# ./fespadea/following/cliclub/followers/MirelesAnthonyL/
# 	0 / 153
# ./fespadea/following/cliclub/followers/james180/
# 	0 / 154
# ./fespadea/following/cliclub/followers/Jazzer/
# ./fespadea/following/cliclub/followers/mshul/
# 	0 / 155
# ./fespadea/following/cliclub/followers/Jashezilla/
# 	0 / 156
# ./fespadea/following/cliclub/followers/shastacat/
# ./fespadea/following/cliclub/followers/jrocket1/
# 	0 / 157
# 	0 / 158
# ./fespadea/following/cliclub/studios/cliclub/
# 	0 / 159
# 	0 / 160
# 	0 / 161
# ./fespadea/following/supermarioboy/studios/Danny_the_Dueces_Gallery/
# ./fespadea/following/supermarioboy/projects/add_yourself_running_from_The_Mega_Bill-2/
# ./fespadea/following/supermarioboy/projects/add_yourself_runing_from_giant_mario_/
# ./fespadea/following/supermarioboy/projects/super_kirby_bros2/
# 	0 / 162
# ./fespadea/following/supermarioboy/projects/Nuclear_City_-_In_the_wild_Incomplete1/
# 	0 / 163
# ./fespadea/following/supermarioboy/projects/ADD_YOURSELF_RUNNING_FROM_WEEGEE11/
# 	0 / 164
# ./fespadea/following/supermarioboy/projects/add_your_self_fighting/
# ./fespadea/following/supermarioboy/projects/toot/
# 	0 / 165
# ./fespadea/following/supermarioboy/projects/add_yourself_running_from_The_Mega_Bill-211/
# 	0 / 166
# 	0 / 167
# ./fespadea/following/supermarioboy/projects/add_your_self_walking111/
# 	0 / 168
# ./fespadea/following/supermarioboy/projects/add_your_self_in_space/
# ./fespadea/following/supermarioboy/projects/MARIO_TIME__21/
# 	0 / 169
# ./fespadea/following/supermarioboy/projects/addyourself_doing_anything/
# 	0 / 170
# ./fespadea/following/supermarioboy/projects/Add_yourself_running_or_flying_from_a_mob_of_weege_slaves1/
# ./fespadea/following/supermarioboy/projects/add_your_self_spinging1/
# 	0 / 171
# ./fespadea/following/supermarioboy/projects/dead_taco/
# 	0 / 172
# ./fespadea/following/supermarioboy/following/toadandfriends/
# ./fespadea/following/supermarioboy/following/Miloticmadness/
# 	0 / 173
# 	0 / 174
# 	0 / 175
# ./fespadea/following/supermarioboy/followers/ilovebugs/
# 	0 / 176
# ./fespadea/following/spark_the_hedgehog/favorites/ULTIMATE_SONIC_SPRITES/
# ./fespadea/following/spark_the_hedgehog/followers/DarkShadowVoid/
# ./fespadea/following/spark_the_hedgehog/followers/yoshi1229/
# ./fespadea/following/spark_the_hedgehog/followers/BeyBlade1333/
# 	0 / 177
# ./fespadea/following/spark_the_hedgehog/followers/darkbydayX/
# 	0 / 178
# 	0 / 179
# ./fespadea/following/spark_the_hedgehog/followers/sunshinthehedgehog/
# 	0 / 180
# ./fespadea/following/spark_the_hedgehog/followers/Animorphs2/
# 	0 / 181
# 	0 / 182
# 	0 / 183
# ./fespadea/following/spark_the_hedgehog/followers/allen08/
# ./fespadea/following/spark_the_hedgehog/followers/Better_Than_Revenge/
# ./fespadea/following/spark_the_hedgehog/followers/madaraUchihaX/
# 	0 / 184
# ./fespadea/following/spark_the_hedgehog/followers/iamsonic/
# ./fespadea/following/spark_the_hedgehog/followers/NESWario/
# 	0 / 185
# 	0 / 186
# ./fespadea/following/spark_the_hedgehog/followers/Lenare/
# 	0 / 187
# ./fespadea/following/spark_the_hedgehog/followers/Havemostfriends/
# 	0 / 188
# 	0 / 189
# ./fespadea/following/spark_the_hedgehog/followers/nickc01/
# ./fespadea/following/spark_the_hedgehog/followers/fadi_hedgehog/
# 	0 / 190
# ./fespadea/following/spark_the_hedgehog/followers/WeirdyMike/
# 	0 / 191
# ./fespadea/following/spark_the_hedgehog/followers/FerretJoe/
# ./fespadea/following/spark_the_hedgehog/followers/Sonic_BlueBlur/
# 	0 / 192
# 	0 / 193
# ./fespadea/following/spark_the_hedgehog/followers/mrslippy913/
# ./fespadea/following/spark_the_hedgehog/followers/dbn300100/
# 	0 / 194
# 	0 / 195
# ./fespadea/following/spark_the_hedgehog/followers/knoa_the_hedgehog/
# ./fespadea/following/spark_the_hedgehog/followers/snowman2000/
# 	0 / 196
# ./fespadea/following/spark_the_hedgehog/following/Food-dude/
# 	0 / 197
# ./fespadea/following/spark_the_hedgehog/following/kingkrab3/
# 	0 / 198
# 	0 / 199
# ./fespadea/following/spark_the_hedgehog/following/Falleo/
# 	0 / 200
# 	0 / 201
# 	0 / 202
# ./fespadea/following/spark_the_hedgehog/following/Danielthehedgehog/
# ./fespadea/following/spark_the_hedgehog/following/ReiTheHedgehog/
# 	0 / 203
# ./fespadea/following/spark_the_hedgehog/following/ScratchWar/
# 	0 / 204
# 	0 / 205
# ./fespadea/following/spark_the_hedgehog/projects/sonic_rpg_part_1/
# ./fespadea/following/spark_the_hedgehog/projects/my_logo/
# ./fespadea/following/spark_the_hedgehog/projects/add_yourself_eascaping_the_deathegg/
# ./fespadea/following/spark_the_hedgehog/projects/Add_yourself_trying_to_get_Katrina_off_the_pole/
# 	0 / 206
# ./fespadea/following/spark_the_hedgehog/projects/stqfte_demo_v.1/
# 	0 / 207
# ./fespadea/following/spark_the_hedgehog/projects/stqfte_2nd_boss_defeted/
# 	0 / 208
# ./fespadea/following/spark_the_hedgehog/projects/stqfte_1st_boss_defeted/
# 	0 / 209
# ./fespadea/following/spark_the_hedgehog/projects/stqfte_title_screen/
# ./fespadea/following/spark_the_hedgehog/projects/sonic_4_HQ_sprites/
# ./fespadea/following/spark_the_hedgehog/projects/Customize_Your_Own_DS1111111111/
# ./fespadea/following/spark_the_hedgehog/projects/sthqfte/
# 	0 / 210
# ./fespadea/following/spark_the_hedgehog/studios/the_sonic_sprites_company/
# ./fespadea/following/spark_the_hedgehog/studios/sonic_and_the_quest_for_the_emralds/
# 	0 / 211
# 	0 / 212
# 	0 / 213
# ./fespadea/following/darthvader424242/projects/pokecat_battle/
# ./fespadea/following/darthvader424242/projects/omg_just_watch/
# ./fespadea/following/darthvader424242/projects/shoop_da_woop/
# ./fespadea/following/darthvader424242/projects/cats_focal_cord_explodes/
# ./fespadea/following/darthvader424242/projects/fourth_o_july/
# ./fespadea/following/darthvader424242/projects/random_cat/
# ./fespadea/following/darthvader424242/projects/meet_mech_and_blob/
# ./fespadea/following/darthvader424242/projects/mechbot_part_1/
# ./fespadea/following/darthvader424242/projects/mech_part_3/
# 	0 / 214
# ./fespadea/following/darthvader424242/projects/The_Race/
# ./fespadea/following/bowser555/projects/Total_Nintendo_and_Sega_Extreme_episode_11_part_1/
# ./fespadea/following/bowser555/projects/Total_nintendo_and_Sega_extreme_episode_11_part_2/
# ./fespadea/following/bowser555/following/waldodogdog/
# 	0 / 215
# 	0 / 216
# ./fespadea/following/bowser555/following/Anko6/
# ./fespadea/following/bowser555/following/Gamer4life/
# 	0 / 217
# 	0 / 218
# ./fespadea/following/bowser555/followers/rainman123/
# 	0 / 219
# ./fespadea/following/bowser555/followers/BestFriends55/
# 	0 / 220
# ./fespadea/following/bowser555/followers/lucari0/
# ./fespadea/following/bowser555/followers/KelynC/
# 	0 / 221
# 	0 / 222
# 	0 / 223
# ./fespadea/following/bowser555/followers/Mariolunatic/
# ./fespadea/following/bowser555/followers/MostFriends/
# ./fespadea/following/bowser555/followers/josh03/
# 	0 / 224
# ./fespadea/following/bowser555/followers/SJRCS_009/
# 	0 / 225
# 	0 / 226
# ./fespadea/following/bowser555/followers/manhani/
# 	0 / 227
# ./fespadea/following/bowser555/followers/justintime5/
# ./fespadea/following/bowser555/followers/kiekejo/
# 	0 / 228
# 	0 / 229
# ./fespadea/following/bowser555/followers/elephant1/
# 	0 / 230
# ./fespadea/following/bowser555/followers/juizdefora/
# ./fespadea/following/bowser555/followers/pikachu210/
# 	0 / 231
# ./fespadea/following/bowser555/followers/designer45/
# 	0 / 232
# ./fespadea/following/bowser555/followers/gagafan123/
# 	0 / 233
# ./fespadea/following/bowser555/followers/DanielandDBABIFRESH/
# 	0 / 234
# 	0 / 235
# ./fespadea/following/bowser555/followers/makaylacouch/
# 	0 / 236
# ./fespadea/following/bowser555/followers/TrainMaster45874/
# ./fespadea/following/bowser555/followers/Yoshi64555/
# 	0 / 237
# 	0 / 238
# 	0 / 239
# ./fespadea/following/Pointlessstuff/followers/oakridgedaniel/
# 	0 / 240
# ./fespadea/following/Pointlessstuff/followers/djdaniel1738/
# ./fespadea/following/Pointlessstuff/followers/jamesgeneh/
# ./fespadea/following/Pointlessstuff/followers/arthurvader/
# 	0 / 241
# 	0 / 242
# ./fespadea/following/Pointlessstuff/followers/mileylover101/
# ./fespadea/following/Pointlessstuff/followers/Kassy37/
# 	0 / 243
# ./fespadea/following/Pointlessstuff/followers/jessieandfall/
# 	0 / 244
# ./fespadea/following/Pointlessstuff/followers/Ilovestarwars2/
# 	0 / 245
# 	0 / 246
# 	0 / 247
# ...
# 	0 / 1859
# ./fespadea/following/Axarr/followers/Opt1musPr1meK/
# ./fespadea/following/Axarr/followers/pusheen509/
# ./fespadea/following/Axarr/followers/Iditaroid/
# 	0 / 1860
# ./fespadea/following/Axarr/followers/iBallisticSquiddles/
# ./fespadea/following/Axarr/followers/alex345/
# 	0 / 1861
# ./fespadea/following/Axarr/followers/CartoonAnimator/
# 	0 / 1862
# 	0 / 1863
# ./fespadea/following/Axarr/followers/aminelakhal/
# ./fespadea/following/Axarr/followers/Luxturna/
# 	0 / 1864
# ./fespadea/following/Axarr/followers/logandonut/
# 	0 / 1865
# 	0 / 1866
# ./fespadea/following/Axarr/followers/eject5/
# ./fespadea/following/Axarr/followers/ErniMan/
# 	0 / 1867
# 	0 / 1868
# ./fespadea/following/Axarr/followers/phillipw123456789/
# ./fespadea/following/Axarr/followers/srx2002/
# 	0 / 1869
# 	0 / 1870
# ./fespadea/following/Axarr/followers/GownacthGogie/
# ./fespadea/following/Axarr/followers/Silverseer/
# 	0 / 1871
# 	0 / 1872
# ./fespadea/following/Axarr/followers/zombie123abc/
# ./fespadea/following/Axarr/followers/imaperson123/
# 	0 / 1873
# ./fespadea/following/Axarr/followers/doritos40000/
# 	0 / 1874
# 	0 / 1875
# ./fespadea/following/Axarr/followers/gid555/
# 	0 / 1876
# ./fespadea/following/Axarr/followers/taddl/
# 	0 / 1877
# ./fespadea/following/Axarr/followers/supermariomj64/
# 	0 / 1878
# 	0 / 1879
# ./fespadea/following/Axarr/followers/Flaremasta1/
# 	0 / 1880
# ./fespadea/following/Axarr/followers/rocket964/
# ./fespadea/following/Axarr/followers/walkingzombie/
# 	0 / 1881
# ./fespadea/following/Axarr/followers/Beaniebabyfan2/
# ./fespadea/following/Axarr/followers/Xion777/
# 	0 / 1882
# ./fespadea/following/Axarr/followers/XUDI/
# 	0 / 1883
# 	0 / 1884
# ./fespadea/following/Axarr/followers/hooklee/
# 	0 / 1885
# ./fespadea/following/Axarr/followers/eventexception/
# ./fespadea/following/Axarr/followers/Erni68/
# 	0 / 1886
# 	0 / 1887
# 	0 / 1888
# ./fespadea/following/Axarr/followers/Snowydude/
# 	0 / 1889
# ./fespadea/following/Axarr/followers/ctjet/
# 	0 / 1890
# ./fespadea/following/Axarr/followers/Aidan/
# ./fespadea/following/Axarr/followers/51037/
# 	0 / 1891
# ./fespadea/following/Axarr/followers/madman95/
# 	0 / 1892
# ./fespadea/following/Axarr/followers/Thescratch3/
# 	0 / 1893
# ./fespadea/following/Axarr/followers/NathynHawk/
# 	0 / 1894
# 	0 / 1895
# ./fespadea/following/Axarr/followers/BladeSpartan/
# 	0 / 1896
# 	0 / 1897
# ./fespadea/following/Axarr/studios/Axarrs_Art_Projects/
# 	0 / 1898
# ./fespadea/following/Flaredaeevee/followers/tigerwolf120/
# ./fespadea/following/Flaredaeevee/followers/Rocelliefanstarz/
# ./fespadea/following/Flaredaeevee/followers/SticksTheBadgerXP72/
# 	0 / 1899
# 	0 / 1900
# ./fespadea/following/Flaredaeevee/followers/dark_melody/
# 	0 / 1901
# ./fespadea/following/Flaredaeevee/followers/jjanderson1/
# ./fespadea/following/Flaredaeevee/followers/-SkyStar-/
# 	0 / 1902
# ./fespadea/following/Flaredaeevee/followers/meowthk9/
# ./fespadea/following/Flaredaeevee/followers/westley51/
# 	0 / 1903
# ./fespadea/following/Flaredaeevee/followers/csumter/
# 	0 / 1904
# ./fespadea/following/Flaredaeevee/followers/JJS15/
# 	0 / 1905
# 	0 / 1906
# ./fespadea/following/Flaredaeevee/followers/GamesPeoplePlay/
# ./fespadea/following/Flaredaeevee/followers/vivpup99/
# 	0 / 1907
# ./fespadea/following/Flaredaeevee/followers/tj7/
# 	0 / 1908
# ./fespadea/following/Flaredaeevee/followers/tosco97/
# 	0 / 1909
# 	0 / 1910
# ./fespadea/following/Flaredaeevee/followers/NinjaPenguin42/
# 	0 / 1911
# 	0 / 1912
# ./fespadea/following/Flaredaeevee/followers/leoniecute/
# ./fespadea/following/Flaredaeevee/followers/warriorbunny/
# 	0 / 1913
# ./fespadea/following/Flaredaeevee/followers/ZoroarkandZoruaDS/
# 	0 / 1914
# ./fespadea/following/Flaredaeevee/followers/Lunastar-/
# ./fespadea/following/Flaredaeevee/followers/Splodgey/
# 	0 / 1915
# ./fespadea/following/Flaredaeevee/following/CatQueen/
# 	0 / 1916
# ./fespadea/following/Flaredaeevee/following/Puprup/
# 	0 / 1917
# 	0 / 1918
# 	0 / 1919
# ./fespadea/following/Flaredaeevee/following/kttn56/
# 	0 / 1920
# ./fespadea/following/Flaredaeevee/following/LittleWarrior12/
# ./fespadea/following/Flaredaeevee/following/pikachi/
# 	0 / 1921
# ./fespadea/following/Flaredaeevee/following/ChannyCM/
# 	0 / 1922
# ./fespadea/following/Flaredaeevee/following/Foxstar192/
# 	0 / 1923
# 	0 / 1924
# ./fespadea/following/Flaredaeevee/following/CalicoKitty/
# ./fespadea/following/Flaredaeevee/following/imbeast/
# ./fespadea/following/Flaredaeevee/following/capsrock_it/
# 	0 / 1925
# ./fespadea/following/Flaredaeevee/following/Oshawott/
# 	0 / 1926
# ./fespadea/following/Flaredaeevee/following/Snivy/
# 	0 / 1927
# 	0 / 1928
# ./fespadea/following/Flaredaeevee/following/Tepig/
# ./fespadea/following/Flaredaeevee/following/Walrus117/
# 	0 / 1929
# 	0 / 1930
# 	0 / 1931
# ./fespadea/following/Flaredaeevee/following/cheatahstar/
# 	0 / 1932
# 	0 / 1933
# ./fespadea/following/Flaredaeevee/following/lnstockb/
# ./fespadea/following/Flaredaeevee/following/PuppyPerse123/
# 	0 / 1934
# ./fespadea/following/Flaredaeevee/following/The-Lightning-Cat/
# 	0 / 1935
# 	0 / 1936
# ./fespadea/following/Flaredaeevee/following/snowpelt/
# ./fespadea/following/Flaredaeevee/following/Dinosaur-Apocalypse/
# ./fespadea/following/Flaredaeevee/projects/crazy_bird_XD_contest/
# ./fespadea/following/Flaredaeevee/projects/Recent_arts/
# 	0 / 1937
# ./fespadea/following/Flaredaeevee/projects/Request_time/
# 	0 / 1938
# ./fespadea/following/Flaredaeevee/projects/Animation_W.I.P/
# 	0 / 1939
# 	0 / 1940
# ./fespadea/following/Flaredaeevee/projects/bluekitsstars_birth_it_doesent_have_the_actual_birth/
# ./fespadea/following/Flaredaeevee/projects/bluey/
# 	0 / 1941
# 	0 / 1942
# ./fespadea/following/Flaredaeevee/projects/I_RULE_DA_WORLD_i_has_da_same_name_as_da_person_in_da_song/
# 	0 / 1943
# ./fespadea/following/Flaredaeevee/projects/Scourge_like_cat_colouring_contestread_notes/
# 	0 / 1944
# ./fespadea/following/Flaredaeevee/projects/one_of_my_pokesonas/
# 	0 / 1945
# 	0 / 1946
# ./fespadea/followers/cookie135/following/LEAD/
# 	0 / 1947
# ./fespadea/followers/cookie135/following/rs3/
# ./fespadea/followers/cookie135/following/Prestige/
# 	0 / 1948
# ./fespadea/followers/cookie135/following/glitchfinder/
# 	0 / 1949
# 	0 / 1950
# ./fespadea/projects/bobs_friend/remixes/SHDS/commentUsers/Leopardheart/
# ./fespadea/projects/bobs_friend/remixes/SHDS/studios/BananaPals/
# 0 / 1
# ./fespadea/projects/add_yourself_flying1REMIXED1/remixes/add_yourself_flying1REMIXED11/studios/The_EVERYTHING_Studio/
# 0 / 2
# ./fespadea/projects/for_swifties_background_characters/studios/School_dilemma_entrys/managers/vc599/
# ./fespadea/projects/for_swifties_background_characters/studios/School_dilemma_entrys/projects/Background_person_for_School_Delima/
# ./fespadea/projects/for_swifties_background_characters/studios/School_dilemma_entrys/projects/Me_in_swifty_style/
# 0 / 3
# ./fespadea/projects/for_swifties_background_characters/studios/School_dilemma_entrys/projects/New_Charactor_Contest/
# 0 / 4
# 0 / 5
# ./fespadea/projects/for_swifties_background_characters/studios/School_dilemma_entrys/projects/Me_for_Swifty2s_School_Dilema/
# ./fespadea/projects/for_swifties_background_characters/studios/School_dilemma_entrys/projects/for_swiftys_project/
# 0 / 6
# 0 / 7
# ./fespadea/projects/for_swifties_background_characters/studios/School_dilemma_entrys/projects/for_swifty2_entry_for_school_dilema/
# 0 / 8
# ./fespadea/projects/for_swifties_background_characters/studios/School_dilemma_entrys/projects/contest._OMG1/
# 0 / 9
# ./fespadea/projects/for_swifties_background_characters/studios/School_dilemma_entrys/projects/Entry_for_swifty_and_bananaguy1000/
# 0 / 10
# ./fespadea/projects/for_swifties_background_characters/studios/School_dilemma_entrys/projects/Max_for_SW/
# 0 / 11
# 0 / 12
# ./fespadea/projects/for_swifties_background_characters/studios/School_dilemma_entrys/projects/contest_rubber_chicken/
# ./fespadea/projects/for_swifties_background_characters/studios/School_dilemma_entrys/projects/School_Dilema_entry/
# ./fespadea/projects/for_swifties_background_characters/studios/School_dilemma_entrys/projects/how_swifty2_might_have_drawn_this_guy_i_made_up/
# 0 / 13
# 0 / 14
# ./fespadea/projects/for_swifties_background_characters/studios/School_dilemma_entrys/projects/my_entry_for_swifty2/
# 0 / 15
# ./fespadea/projects/for_swifties_background_characters/studios/School_dilemma_entrys/projects/My_swifty2_charecter/
# 0 / 16
# ./fespadea/projects/for_swifties_background_characters/studios/School_dilemma_entrys/projects/for_swifty_for_school_dilema._/
# 0 / 17
# ./fespadea/projects/shoop_the_pus/studios/shoop_da_woop/curators/Tpointer56/
# 0 / 18
# ./fespadea/projects/shoop_the_pus/studios/shoop_da_woop/curators/stkpro11/
# 0 / 19
# ./fespadea/projects/shoop_the_pus/studios/shoop_da_woop/managers/Shantae-Genie/
# 0 / 20
# 0 / 21
# 0 / 22
# ./fespadea/projects/some_art/studios/Drawing_and_other_arts/projects/Ruki_Drawing/
# ./fespadea/projects/some_art/studios/Drawing_and_other_arts/projects/grandpapy_and_the_creepy_things/
# ./fespadea/projects/some_art/studios/Drawing_and_other_arts/projects/clayman_goes_squish/
# ./fespadea/projects/some_art/studios/Drawing_and_other_arts/projects/Untitled/
# 0 / 23
# 0 / 24
# ./fespadea/projects/some_art/studios/Drawing_and_other_arts/projects/EPIC_knight/
# 0 / 25
# 0 / 26
# ./fespadea/projects/some_art/studios/Drawing_and_other_arts/projects/MicroScratch_XTR3ME/
# ./fespadea/projects/some_art/studios/Drawing_and_other_arts/projects/Browser_Vs._Mario/
# 0 / 27
# ./fespadea/projects/some_art/studios/Drawing_and_other_arts/projects/Interactive_Turtle/
# ./fespadea/projects/some_art/studios/Drawing_and_other_arts/projects/Change_color_effect_by-function/
# 0 / 28
# 0 / 29
# 0 / 30
# ./fespadea/projects/Add_yourself_Trying_to_catch_sonic11/remixes/Add_yourself_Trying_to_catch_sonic1112/remixes/Dude_trys_to_beat_Sonic/
# 0 / 31
# 0 / 32
# ./fespadea/projects/toon_bros._sprite_pack_small/studios/Untitled_Studio/projects/Super_Sonic_World_Mania_HD_2.5_Remix_Turbo/
# ./fespadea/projects/toon_bros._sprite_pack_small/studios/Untitled_Studio/managers/foxisse211/
# 0 / 33
# Image not found: https://cdn2.scratch.mit.edu/get_image/user/57586980_90x90.png?v=
# 0 / 34
# ./fespadea/projects/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/remixes/me_on_him/commentUsers/Marshmallow012345678/
# ./fespadea/projects/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/remixes/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1_remix/studios/funny_stuff/
# ./fespadea/projects/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/remixes/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1_remix/studios/5uck/
# ./fespadea/projects/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/remixes/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1_remix/studios/HEHEHEHEHE/
# 0 / 35
# 0 / 36
# ./fespadea/projects/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/remixes/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1_remix/studios/Two_Guys_YAH/
# ./fespadea/projects/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/remixes/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1_remix/studios/Snowylion64s_Stuff/
# 0 / 37
# 0 / 38
# 0 / 39
# ./fespadea/projects/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/remixes/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1_remix/studios/Goomba_Group_2/
# ./fespadea/projects/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/remixes/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1_remix/studios/Add_Projects_and_Become_Popular/
# 0 / 40
# ./fespadea/projects/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/remixes/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1_remix/studios/ADD_EVERYthING_ADD_EVERYoNE/
# 0 / 41
# ./fespadea/projects/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/remixes/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1_remix/remixes/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1_remix_remix/
# ./fespadea/projects/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/remixes/ADD_YOURSELF_RUNNING_FROM_TEAM_DARK/commentUsers/l0l1o1/
# 0 / 42
# ./fespadea/projects/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/remixes/ADD_YOURSELF_RUNNING_FROM_TEAM_DARK/commentUsers/Yaya_Games123/
# ./fespadea/projects/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/remixes/ADD_YOURSELF_RUNNING_FROM_TEAM_DARK/remixes/ADD_YOURSELF_RUNNING_FROM_PUMPKIN_SPIDER/
# 0 / 43
# ./fespadea/projects/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/remixes/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/remixes/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN11/
# 0 / 44
# ./fespadea/projects/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/remixes/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/studios/Good_ideas/
# 0 / 45
# ./fespadea/projects/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/remixes/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/studios/Every_Project_in_Scratch/
# 0 / 46
#   + Exception Group Traceback (most recent call last):
#   |   File "c:\Users\fespa\anaconda3\envs\forFun\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#   |     exec(code_obj, self.user_global_ns, self.user_ns)
#   |   File "C:\Users\fespa\AppData\Local\Temp\ipykernel_8212\1654812823.py", line 2, in <module>
#   |     trio.run(getUserData, authData["username"], authData["level"], "./", authData["username"], authData["x-token"])
#   |   File "c:\Users\fespa\anaconda3\envs\forFun\Lib\site-packages\trio\_core\_run.py", line 2303, in run
#   |     raise runner.main_task_outcome.error
#   |   File "C:\Users\fespa\AppData\Local\Temp\ipykernel_8212\2816425689.py", line 324, in getUserData
#   |     async with trio.open_nursery() as nursery:
#   |   File "c:\Users\fespa\anaconda3\envs\forFun\Lib\site-packages\trio\_core\_run.py", line 963, in __aexit__
#   |     raise combined_error_from_nursery
#   | ExceptionGroup: Exceptions from Trio nursery (1 sub-exception)
#   +-+---------------- 1 ----------------
#     | Exception Group Traceback (most recent call last):
#     |   File "C:\Users\fespa\AppData\Local\Temp\ipykernel_8212\1489676143.py", line 93, in getReturn
#     |     assignee[location] = await func(*args)
#     |                          ^^^^^^^^^^^^^^^^^
#     |   File "C:\Users\fespa\AppData\Local\Temp\ipykernel_8212\2816425689.py", line 80, in getProjectData
#     |     async with trio.open_nursery() as nursery:
#     |   File "c:\Users\fespa\anaconda3\envs\forFun\Lib\site-packages\trio\_core\_run.py", line 963, in __aexit__
#     |     raise combined_error_from_nursery
#     | ExceptionGroup: Exceptions from Trio nursery (1 sub-exception)
#     +-+---------------- 1 ----------------
#       | Exception Group Traceback (most recent call last):
#       |   File "C:\Users\fespa\AppData\Local\Temp\ipykernel_8212\1489676143.py", line 93, in getReturn
#       |     assignee[location] = await func(*args)
#       |                          ^^^^^^^^^^^^^^^^^
#       |   File "C:\Users\fespa\AppData\Local\Temp\ipykernel_8212\2816425689.py", line 80, in getProjectData
#       |     async with trio.open_nursery() as nursery:
#       |   File "c:\Users\fespa\anaconda3\envs\forFun\Lib\site-packages\trio\_core\_run.py", line 963, in __aexit__
#       |     raise combined_error_from_nursery
#       | ExceptionGroup: Exceptions from Trio nursery (1 sub-exception)
#       +-+---------------- 1 ----------------
#         | Traceback (most recent call last):
#         |   File "C:\Users\fespa\AppData\Local\Temp\ipykernel_8212\1489676143.py", line 93, in getReturn
#         |     assignee[location] = await func(*args)
#         |                          ^^^^^^^^^^^^^^^^^
#         |   File "C:\Users\fespa\AppData\Local\Temp\ipykernel_8212\2816425689.py", line 41, in getProjectData
#         |     await imageGet(project["projectInfo"]["image"], outputPath)
#         |   File "C:\Users\fespa\AppData\Local\Temp\ipykernel_8212\1793751010.py", line 67, in imageGet
#         |     shutil.copy(imageBackupPath, imagePath)
#         |   File "c:\Users\fespa\anaconda3\envs\forFun\Lib\shutil.py", line 435, in copy
#         |     copyfile(src, dst, follow_symlinks=follow_symlinks)
#         |   File "c:\Users\fespa\anaconda3\envs\forFun\Lib\shutil.py", line 262, in copyfile
#         |     with open(dst, 'wb') as fdst:
#         |          ^^^^^^^^^^^^^^^
#         | FileNotFoundError: [Errno 2] No such file or directory: './fespadea/projects/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/remixes/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1_remix/remixes/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1_remix_remix/904416464_480x360.png'
#         +------------------------------------

# %%
dumpJSON(authData["username"] + "_projects", projectsToDownload)
dumpGeneric(authData["username"] + "_urls", urlsToDownload, type="txt")
# Out:
# './fespadea_urls_including_descended.txt'

# %%
p = subprocess.Popen(['node', './downloadProject.js'], stdout=subprocess.PIPE)
for line in iter(p.stdout.readline, b""):
        print(line.decode(), end="")
# Out:
# Done

# %%
os.path.exists("./fespadea/projects/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/remixes/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1_remix/remixes/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1_remix_remix/")
# Out:
# True

# %%
with open("./fespadea/projects/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/remixes/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1_remix/remixes/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1_remix_remix/test23043.txt", 'wb') as fdst:
    print(fdst)
# Out:
# <_io.BufferedWriter name='./fespadea/projects/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1/remixes/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1_remix/remixes/ADD_YOURSELF_RUNNING_FROM_GIANT_STICKMAN1_remix_remix/test23043.txt'>
